# %% [markdown]
# # Data wrangling with Python

# %% [markdown]
# Dataframe creation
#
# 1. Creating a dataframe from dictionary
# 2. from csv and excel
#
# Data understanding
#
# 1. Datframe visual inspection
# 2. Datatypes
# 3. Locating rows and columns
# 4. Subsetting
# 5. Frequency counts
# 6. Summary statistics
#
# Data Preparation
#
# 1. Tidy data - melting and pivoting and Resetting index of a dataframe
# 2. Adding and deleting the columns
# 3. Adding and deleting the rows
# 4. Renaming columns and rows
# 5. Creating bins(categories) of values of a variables
# 6. Sorting data
# 7. Grouping data
# 8. Finding and concatenating
# 8. Appending and merging of Dataframes
# 9. Converting into different datatypes
# 10. Using regular expressions to clean strings
# 11. User defined function and Lambda function
# 12. Duplicate and missing data
# 13. Testing with Asserts
# 14. Exporting to csv/Excel

# %% [raw]
# Creating a dataframe from dictionary

# %%
import pandas as pd

# %%
dict1 = {
"country":["Brazil", "Russia", "India", "China", "South Africa"],
"capital":["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
"area":[8.516, 17.10, 3.286, 9.597,1.221],
"population":[200.4, 143.5, 1252, 1357,52.98] }

# %%
df = pd.DataFrame(dict1)
df
# Out:
#      area    capital       country  population
# 0   8.516   Brasilia        Brazil      200.40
# 1  17.100     Moscow        Russia      143.50
# 2   3.286  New Delhi         India     1252.00
# 3   9.597    Beijing         China     1357.00
# 4   1.221   Pretoria  South Africa       52.98

# %%
df = pd.DataFrame(dict1, 
                  index = ['A','B','C','D','E'], 
                  columns = ['country','capital','area','population'])
df
# Out:
#         country    capital    area  population
# A        Brazil   Brasilia   8.516      200.40
# B        Russia     Moscow  17.100      143.50
# C         India  New Delhi   3.286     1252.00
# D         China    Beijing   9.597     1357.00
# E  South Africa   Pretoria   1.221       52.98

# %%
dict1['country'][0]
# Out:
# 'Brazil'

# %%
df.loc['A','country']
# Out:
# 'Brazil'

# %%
dict2 = {
"country":"South Africa",
"capital":"Pretoria",
"area":1.22,
"population":52.98}

# %%
x = pd.Series(dict2, index= ["country", 'capital','area','population'])
x
# Out:
# country       South Africa
# capital           Pretoria
# area                  1.22
# population           52.98
# dtype: object

# %%
pd.Series(['South Africa','Pretoria',1.22,52.98], index =['A','B','C','D'])
# Out:
# A    South Africa
# B        Pretoria
# C            1.22
# D           52.98
# dtype: object

# %%
brics = pd.DataFrame(dict1, 
                     columns = ["country", 'capital','area','population'],
                     index = [('A'),('B'),('C'),("D"),('E')])
brics
# Out:
#         country    capital    area  population
# A        Brazil   Brasilia   8.516      200.40
# B        Russia     Moscow  17.100      143.50
# C         India  New Delhi   3.286     1252.00
# D         China    Beijing   9.597     1357.00
# E  South Africa   Pretoria   1.221       52.98

# %% [raw]
# creating dataframe using lists

# %%
lst1 = ['Brazil','Brasilia',8.516,200.40]
lst2 = ['South Africa','Pretoria',1.22,52.98]

# %%
pd.DataFrame([lst1,lst2])
# Out:
#               0         1      2       3
# 0        Brazil  Brasilia  8.516  200.40
# 1  South Africa  Pretoria  1.220   52.98

# %%
pd.DataFrame([['Brazil','Brasilia',8.516,200.40],
             ['Russia','Moscow',17.100,143.50]],
            columns = ["country", 'capital','area','population'],
            index = ['A','B'])
# Out:
#   country   capital    area  population
# A  Brazil  Brasilia   8.516       200.4
# B  Russia    Moscow  17.100       143.5

# %%
## Series 
ser = pd.Series([200.4, 143.5, 1252, 1357, 52.98],index =["Brazil", "Russia", "India", "China", "South Africa"])
ser
# Out:
# Brazil           200.40
# Russia           143.50
# India           1252.00
# China           1357.00
# South Africa      52.98
# dtype: float64

# %%
print(ser['Russia'])
ser.Russia
# Out:
# 143.5
# 143.5

# %%
pwd()
# Out:
# '/Users/nimisha/Desktop/Untitled Folder'

# %%
import os
os.getcwd()
# Out:
# '/Users/nimisha/Desktop/Untitled Folder'

# %%
os.chdir('/Users/nimisha/Downloads/Ds Simplilearn data')

# %%
C:\\Usersb

# %%
'a 12 \n w 23'
# Out:
# 'a 12 \n w 23'

# %%
# ?pd.read_excel

# %%
samp = pd.read_csv("Datasets/sample_data.csv")

# %%
type(samp)
# Out:
# pandas.core.frame.DataFrame

# %%
samp.head()
# Out:
#     ID  Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# 0   70       0     4    1       1     1    57     52     41     47   57
# 1  121       1     4    2       1     3    68     59     53     63   61
# 2   86       0     4    3       1     1    44     33     54     58   31
# 3  141       0     4    3       1     3    63     44     47     53   56
# 4  172       0     4    2       1     2    47     52     57     53   61

# %%
samp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
# ID        200 non-null int64
# Gender    200 non-null int64
# Race      200 non-null int64
# SEB       200 non-null int64
# School    200 non-null int64
# Prog      200 non-null int64
# Read      200 non-null int64
# Write     200 non-null int64
# Math1     200 non-null int64
# Math2     200 non-null int64
# SST       200 non-null int64
# dtypes: int64(11)
# memory usage: 17.3 KB

# %%
brics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, A to E
# Data columns (total 4 columns):
# country       5 non-null object
# capital       5 non-null object
# area          5 non-null float64
# population    5 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 200.0+ bytes

# %%
samp.columns
# Out:
# Index(['ID', 'Gender', 'Race', 'SEB', 'School', 'Prog', 'Read', 'Write',
#        'Math1', 'Math2', 'SST'],
#       dtype='object')

# %%
samp= pd.read_csv("Datasets/Sample_data.csv",
                  index_col = 0)
samp.head()
# Out:
#      Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# ID
# 70        0     4    1       1     1    57     52     41     47   57
# 121       1     4    2       1     3    68     59     53     63   61
# 86        0     4    3       1     1    44     33     54     58   31
# 141       0     4    3       1     3    63     44     47     53   56
# 172       0     4    2       1     2    47     52     57     53   61

# %%
samp_1 = pd.read_csv("Datasets/Sample_data.csv", 
                     index_col = 0,
                  usecols = ['ID','Prog',"Race","Gender","SEB"])

# %%
samp_1.head()
# Out:
#      Gender  Race  SEB  Prog
# ID
# 70        0     4    1     1
# 121       1     4    2     3
# 86        0     4    3     1
# 141       0     4    3     3
# 172       0     4    2     2

# %%
samp_2 = samp_1.reset_index()
# Out:
#       ID  Gender  Race  SEB  Prog
# 0     70       0     4    1     1
# 1    121       1     4    2     3
# 2     86       0     4    3     1
# 3    141       0     4    3     3
# 4    172       0     4    2     2
# 5    113       0     4    2     2
# 6     50       0     3    2     1
# 7     11       0     1    2     2
# 8     84       0     4    2     1
# 9     48       0     3    2     2
# 10    75       0     4    2     3
# 11    60       0     4    2     2
# 12    95       0     4    3     2
# 13   104       0     4    3     2
# 14    38       0     3    1     2
# 15   115       0     4    1     1
# 16    76       0     4    3     2
# 17   195       0     4    2     1
# 18   114       0     4    3     2
# 19    85       0     4    2     1
# 20   167       0     4    2     1
# 21   143       0     4    2     3
# 22    41       0     3    2     2
# 23    20       0     1    3     2
# 24    12       0     1    2     3
# 25    53       0     3    2     3
# 26   154       0     4    3     2
# 27   178       0     4    2     3
# 28   196       0     4    3     2
# 29    29       0     2    1     1
# ..   ...     ...   ...  ...   ...
# 170  119       1     4    1     1
# 171   13       1     1    2     3
# 172   51       1     3    3     1
# 173   26       1     2    3     2
# 174   36       1     3    1     1
# 175  135       1     4    1     2
# 176   59       1     4    2     2
# 177   78       1     4    2     2
# 178   64       1     4    3     3
# 179   63       1     4    1     1
# 180   79       1     4    2     2
# 181  193       1     4    2     2
# 182   92       1     4    3     1
# 183  160       1     4    2     2
# 184   32       1     2    3     3
# 185   23       1     2    1     2
# 186  158       1     4    2     1
# 187   25       1     2    2     1
# 188  188       1     4    3     2
# 189   52       1     3    1     2
# 190  124       1     4    1     3
# 191  175       1     4    3     1
# 192  184       1     4    2     3
# 193   30       1     2    3     2
# 194  179       1     4    2     2
# 195   31       1     2    2     1
# 196  145       1     4    2     3
# 197  187       1     4    2     1
# 198  118       1     4    2     1
# 199  137       1     4    3     2
#
# [200 rows x 5 columns]

# %%
samp_1.reset_index(inplace = True)

# %%
samp_1.head()
# Out:
#     ID  Gender  Race  SEB  Prog
# 0   70       0     4    1     1
# 1  121       1     4    2     3
# 2   86       0     4    3     1
# 3  141       0     4    3     3
# 4  172       0     4    2     2

# %%
samp_1.set_index('ID', inplace = True)

# %%
samp_1.head()
# Out:
#      Gender  Race  SEB  Prog
# ID
# 70        0     4    1     1
# 121       1     4    2     3
# 86        0     4    3     1
# 141       0     4    3     3
# 172       0     4    2     2

# %%
#samp_1.rename({'Gender':'GENDER','Race':'RACE'}, axis = 1)

# %%
samp = pd.read_csv("Datasets/sample_data.csv")
samp.head(2)
# Out:
#     ID  Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# 0   70       0     4    1       1     1    57     52     41     47   57
# 1  121       1     4    2       1     3    68     59     53     63   61

# %%
# view data

# %%
## samp ---> file object of dataframe class type
## head() ---> function
samp.head() ## first 5 rows by default
# Out:
#      Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# ID
# 70        0     4    1       1     1    57     52     41     47   57
# 121       1     4    2       1     3    68     59     53     63   61
# 86        0     4    3       1     1    44     33     54     58   31
# 141       0     4    3       1     3    63     44     47     53   56
# 172       0     4    2       1     2    47     52     57     53   61

# %%
samp.head(2)
# Out:
#     ID  Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# 0   70       0     4    1       1     1    57     52     41     47   57
# 1  121       1     4    2       1     3    68     59     53     63   61

# %%
samp.tail() ## bottom 5 rows by default
# Out:
#       ID  Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# 195   31       1     2    2       2     1    55     59     52     42   56
# 196  145       1     4    2       1     3    42     46     38     36   46
# 197  187       1     4    2       2     1    57     41     57     55   52
# 198  118       1     4    2       1     1    55     62     58     58   61
# 199  137       1     4    3       1     2    63     65     65     53   61

# %%
samp.columns #attribute variables
# Out:
# Index(['ID', 'Gender', 'Race', 'SEB', 'School', 'Prog', 'Read', 'Write',
#        'Math1', 'Math2', 'SST'],
#       dtype='object')

# %%
samp.shape
# Out:
# (200, 11)

# %%
samp.size
# Out:
# 2200

# %%
samp.dtypes
# Out:
# ID        int64
# Gender    int64
# Race      int64
# SEB       int64
# School    int64
# Prog      int64
# Read      int64
# Write     int64
# Math1     int64
# Math2     int64
# SST       int64
# dtype: object

# %% [markdown]
# #### Access Data in dataframe

# %% [raw]
# ## Access a column

# %%
brics['capital'] ## return a series
# Out:
# A     Brasilia
# B       Moscow
# C    New Delhi
# D      Beijing
# E     Pretoria
# Name: capital, dtype: object

# %%
brics.capital ##  returns a Series
# Out:
# A     Brasilia
# B       Moscow
# C    New Delhi
# D      Beijing
# E     Pretoria
# Name: capital, dtype: object

# %%
brics[['capital']] ## returns a Dataframe
# Out:
#      capital
# A   Brasilia
# B     Moscow
# C  New Delhi
# D    Beijing
# E   Pretoria

# %%
brics[['country','capital']]
# Out:
#         country    capital
# A        Brazil   Brasilia
# B        Russia     Moscow
# C         India  New Delhi
# D         China    Beijing
# E  South Africa   Pretoria

# %%
brics[0:3]
# Out:
#   country    capital    area  population
# A  Brazil   Brasilia   8.516       200.4
# B  Russia     Moscow  17.100       143.5
# C   India  New Delhi   3.286      1252.0

# %%
brics.country[0:3]
# Out:
# A    Brazil
# B    Russia
# C     India
# Name: country, dtype: object

# %%
brics[['country','capital']][0:3]
# Out:
#   country    capital
# A  Brazil   Brasilia
# B  Russia     Moscow
# C   India  New Delhi

# %%
## Access Rows and Columns

# %% [markdown]
# ### loc and iloc

# %% [raw]
# dataframe.loc[index] ---> row ---> row name row index or column name

# %%
brics.loc['A', 'country']
# Out:
# 'Brazil'

# %%
brics.loc['A':'D', ['country','capital']]
# Out:
#   country    capital
# A  Brazil   Brasilia
# B  Russia     Moscow
# C   India  New Delhi
# D   China    Beijing

# %%
samp.set_index('ID',inplace = True)

# %%
samp.loc[70:50,['Gender','Prog']]
# Out:
#      Gender  Prog
# ID
# 70        0     1
# 121       1     3
# 86        0     1
# 141       0     3
# 172       0     2
# 113       0     2
# 50        0     1

# %%
samp.loc[[121]] #rows as dataframes
# Out:
#      Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# ID
# 121       1     4    2       1     3    68     59     53     63   61

# %%
brics.loc['A'] ## Series
# Out:
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: A, dtype: object

# %%
samp.loc[[70,121,86]]
# Out:
#      Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# ID
# 70        0     4    1       1     1    57     52     41     47   57
# 121       1     4    2       1     3    68     59     53     63   61
# 86        0     4    3       1     1    44     33     54     58   31

# %%
samp.loc[[70,121,86],["Gender","Race"]]
# Out:
#      Gender  Race
# ID
# 70        0     4
# 121       1     4
# 86        0     4

# %% [raw]
# iloc : actual index ---> row numbers and column numbers

# %%
samp.loc[70:86,'Gender':'Prog']
# Out:
#      Gender  Race  SEB  School  Prog
# ID
# 70        0     4    1       1     1
# 121       1     4    2       1     3
# 86        0     4    3       1     1

# %%
samp.iloc[70:86,0:4]
# Out:
#      Gender  Race  SEB  School
# ID
# 155       0     4    2       1
# 97        0     4    3       1
# 68        0     4    2       1
# 157       0     4    2       1
# 56        0     4    2       1
# 5         0     1    1       1
# 159       0     4    3       1
# 123       0     4    3       1
# 164       0     4    2       1
# 14        0     1    3       1
# 127       0     4    3       1
# 165       0     4    1       1
# 174       0     4    2       2
# 3         0     1    1       1
# 58        0     4    2       1
# 146       0     4    3       1

# %% [raw]
# brics['new_column'] =

# %% [markdown]
# Data Type Conversion

# %%
import numpy as np

# %%
brics['population'] ## Series
# Out:
# A     200.40
# B     143.50
# C    1252.00
# D    1357.00
# E      52.98
# Name: population, dtype: float64

# %%
brics.population.astype('str')
# Out:
# A     200.4
# B     143.5
# C    1252.0
# D    1357.0
# E     52.98
# Name: population, dtype: object

# %%
brics
# Out:
#         country    capital    area  population
# A        Brazil   Brasilia   8.516      200.40
# B        Russia     Moscow  17.100      143.50
# C         India  New Delhi   3.286     1252.00
# D         China    Beijing   9.597     1357.00
# E  South Africa   Pretoria   1.221       52.98

# %%
brics['pop_str']= brics["population"].astype('str')

# %%
brics["new_column"] = [1,2,3,4,5]

# %%
brics
# Out:
#         country    capital    area  population pop_str  new_column
# A        Brazil   Brasilia   8.516      200.40   200.4           1
# B        Russia     Moscow  17.100      143.50   143.5           2
# C         India  New Delhi   3.286     1252.00  1252.0           3
# D         China    Beijing   9.597     1357.00  1357.0           4
# E  South Africa   Pretoria   1.221       52.98   52.98           5

# %%
brics['pop_float']=brics.population.astype(np.complex)

# %%
brics
# Out:
#         country    capital    area  population pop_str  new_column   pop_float
# A        Brazil   Brasilia   8.516      200.40   200.4           1  (200.4+0j)
# B        Russia     Moscow  17.100      143.50   143.5           2  (143.5+0j)
# C         India  New Delhi   3.286     1252.00  1252.0           3   (1252+0j)
# D         China    Beijing   9.597     1357.00  1357.0           4   (1357+0j)
# E  South Africa   Pretoria   1.221       52.98   52.98           5  (52.98+0j)

# %%
brics.country = brics.country.astype('category')

# %%
brics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, A to E
# Data columns (total 7 columns):
# country       5 non-null category
# capital       5 non-null object
# area          5 non-null float64
# population    5 non-null float64
# pop_int       5 non-null int64
# pop_str       5 non-null object
# pop_float     5 non-null float64
# dtypes: category(1), float64(3), int64(1), object(2)
# memory usage: 645.0+ bytes

# %%
brics
# Out:
#         country    capital    area  population  pop_int pop_str  pop_float
# A        Brazil   Brasilia   8.516      200.40      200   200.4     200.40
# B        Russia     Moscow  17.100      143.50      143   143.5     143.50
# C         India  New Delhi   3.286     1252.00     1252  1252.0    1252.00
# D         China    Beijing   9.597     1357.00     1357  1357.0    1357.00
# E  South Africa   Pretoria   1.221       52.98       52   52.98      52.98

# %%
samp.loc[[70,121,86],['Gender','Race']]
# Out:
#     Gender  Race
# ID
# 70       0     4
# 121      1     4
# 86       0     4

# %%
samp.loc[70:86,['Gender','Race']]
# Out:
#     Gender  Race
# ID
# 70       0     4
# 121      1     4
# 86       0     4

# %%
#samp[['Gender','SEB']]

# %%
samp.loc[70:113,['Math1']]
# Out:
#      Math1
# ID
# 70      41
# 121     53
# 86      54
# 141     47
# 172     57
# 113     51

# %%
samp.reset_index(inplace = True)

# %%
samp.set_index('Gender', inplace = True)

# %%
samp.loc[[0]].head(1)
# Out:
#         ID  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# Gender
# 0       70     4    1       1     1    57     52     41     47   57

# %%
samp.Gender = samp.Gender.astype('category')

# %%
samp.Gender.describe()
# Out:
# count     200
# unique      2
# top         1
# freq      109
# Name: Gender, dtype: int64

# %%
brics.loc['A':'D':2,['country','capital']]
# Out:
#   country    capital
# A  Brazil   Brasilia
# C   India  New Delhi

# %%
brics.loc['B':'D','country':'population']
# Out:
#   country    capital    area  population
# B  Russia     Moscow  17.100       143.5
# C   India  New Delhi   3.286      1252.0
# D   China    Beijing   9.597      1357.0

# %%
samp.index
# Out:
# Int64Index([ 70, 121,  86, 141, 172, 113,  50,  11,  84,  48,
#             ...
#             124, 175, 184,  30, 179,  31, 145, 187, 118, 137],
#            dtype='int64', name='ID', length=200)

# %%
samp.reset_index(inplace = True)
samp.set_index('ID', inplace = True)

# %%
samp.loc[[70,121,86],['Gender','Race']]

# %%
samp.iloc[[0,1,2],[0,1]]

# %%
samp.head()
# Out:
#      Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# ID
# 70        0     4    1       1     1    57     52     41     47   57
# 121       1     4    2       1     3    68     59     53     63   61
# 86        0     4    3       1     1    44     33     54     58   31
# 141       0     4    3       1     3    63     44     47     53   56
# 172       0     4    2       1     2    47     52     57     53   61

# %%
sum_ser = samp.Read + samp.Write + samp.Math1 + samp.Math2 +samp.SST

# %% [raw]
# samp.insert(location, name of the column, values)

# %%
## insert a column

# %%
samp.insert(5,'Total',sum_ser)

# %%
samp.head()
# Out:
#      Gender  Race  SEB  School  Prog  Total  Read  Write  Math1  Math2  SST
# ID
# 70        0     4    1       1     1    254    57     52     41     47   57
# 121       1     4    2       1     3    304    68     59     53     63   61
# 86        0     4    3       1     1    220    44     33     54     58   31
# 141       0     4    3       1     3    263    63     44     47     53   56
# 172       0     4    2       1     2    270    47     52     57     53   61

# %%
samp.iloc[:,-5:-1].sum(axis = 0)
# Out:
# Read     10446
# Write    10555
# Math1    10529
# Math2    10370
# dtype: int64

# %%
df.iloc[rows , columns]
df.iloc[rows = : , columns = -5 :-1 : 1 ]

# %%
samp.iloc[:,-5:-1].sum(axis = 1).head(2)
# Out:
# ID
# 70     197
# 121    243
# dtype: int64

# %% [markdown]
# #### axis  -- rows or columns
# #### axis is defined by 0 or 1

# %% [markdown]
# #### axis = 0 ---> column wise operation or row wise reduction
# #### axis = 1 ---> row wise operation or column wise reduction

# %%
## removing Row or column -- drop

# %%
samp.drop('Gender', axis = 1 ).head()
# Out:
#      Race  SEB  School  Prog  Total  Read  Write  Math1  Math2  SST
# ID
# 70      4    1       1     1    254    57     52     41     47   57
# 121     4    2       1     3    304    68     59     53     63   61
# 86      4    3       1     1    220    44     33     54     58   31
# 141     4    3       1     3    263    63     44     47     53   56
# 172     4    2       1     2    270    47     52     57     53   61

# %%
samp.drop(labels = 70, axis = 0).shape
# Out:
# (199, 11)

# %%
# ?samp.drop

# %%
#samp.drop(columns = 'Gender',axis = 1)

# %%
samp --> Gender (0, 1)

# %% [markdown]
# ## Filtering Dataframes

# %%
a =np.array([[1,2,3],[3,4,5],[5,6,7]])
a
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [5, 6, 7]])

# %%
a[(a>2) | (a>5)]
# Out:
# array([3, 3, 4, 5, 5, 6, 7])

# %%
brics = brics.iloc[:,0:4].copy()

# %%
brics.loc[[False,True,False,True,False],[False,True,False,True]]
# Out:
#    capital  population
# B   Moscow       143.5
# D  Beijing      1357.0

# %%
samp[samp['Math1'] >= 35].shape ## expression
# Out:
# (199, 11)

# %%
samp_1 = samp.copy()

# %%
samp_1.loc[(samp_1['Math1'] >50),'Math1' ] = 'Pass'

# %%
samp_1.head()
# Out:
#      Gender  Race  SEB  School  Prog  Total  Read  Write Math1  Math2  SST
# ID
# 70        0     4    1       1     1    254    57     52    41     47   57
# 121       1     4    2       1     3    304    68     59  Pass     63   61
# 86        0     4    3       1     1    220    44     33  Pass     58   31
# 141       0     4    3       1     3    263    63     44    47     53   56
# 172       0     4    2       1     2    270    47     52  Pass     53   61

# %%
samp[(samp['Math1'] >75) ].shape
# Out:
# (0, 11)

# %% [markdown]
# #### & ---> and
# #### | ---> or

# %%
(samp['Math1']>54) & (samp["Math1"]<70)
# Out:
# ID
# 70     False
# 121    False
# 86     False
# 141    False
# 172     True
# 113    False
# 50     False
# 11     False
# 84     False
# 48     False
# 75     False
# 60     False
# 95     False
# 104     True
# 38     False
# 115    False
# 76     False
# 195     True
# 114     True
# 85      True
# 167    False
# 143    False
# 41     False
# 20      True
# 12     False
# 53     False
# 154     True
# 178     True
# 196    False
# 29     False
#        ...
# 119    False
# 13     False
# 51     False
# 26      True
# 36     False
# 135     True
# 59      True
# 78     False
# 64     False
# 63      True
# 79     False
# 193    False
# 92      True
# 160     True
# 32      True
# 23      True
# 158     True
# 25     False
# 188     True
# 52     False
# 124    False
# 175    False
# 184    False
# 30     False
# 179     True
# 31     False
# 145    False
# 187     True
# 118     True
# 137     True
# Name: Math1, Length: 200, dtype: bool

# %%
samp[(samp['Math1']>54) & (samp["Math1"]<70)].shape
# Out:
# (71, 11)

# %%
brics[(brics['country']=='Brazil')|(brics['country']=='Russia')]

# %% [markdown]
# &  -- elementwise
# |  -- elementwise
# ! / not

# %%
np.logical_and(multiple expression seperated by commas)

# %%
samp[np.logical_and(samp['Math1']>54,samp['Math1']<70)].shape
# Out:
# (71, 11)

# %%
brics[np.logical_or(brics['country']=='Brazil',brics['country']=='Russia')]
# Out:
#   country   capital    area  population  pop_int pop_str  pop_float
# A  Brazil  Brasilia   8.516       200.4      200   200.4      200.4
# B  Russia    Moscow  17.100       143.5      143   143.5      143.5

# %%
samp[np.logical_or(samp['Race']==1,samp['Race']==2)].head(2)
# Out:
#     Gender  Race  SEB  School  Prog  Total  Read  Write  Math1  Math2  SST
# ID
# 11       0     1    2       1     2    200    34     46     45     39   36
# 20       0     1    3       1     2    291    60     52     57     61   61

# %%
samp[np.logical_and(
    np.logical_or(samp['Race']==1,samp['Race']==2),samp['Math1']>60)]
# Out:
#     Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# ID
# 27       0     2    2       1     2    53     61     61     57   56
# 21       0     1    2       1     1    44     44     61     50   46
# 24       0     2    2       1     2    52     62     66     47   46
# 33       1     2    1       1     2    57     65     72     54   56
# 26       1     2    3       1     2    60     59     62     61   51
# 32       1     2    3       1     3    50     67     66     66   56
# 23       1     2    1       1     2    65     65     64     58   71

# %%
samp[np.logical_or(samp['Race']==1,samp['Race']==2)].shape
# Out:
# (35, 11)

# %% [markdown]
# #### Fitering a dataframe for values of a variable stored in a list

# %% [raw]
# emp data -- country
# select employees belonging to either of the countries from a given list
# ['India', 'China','Mexico','Japan','Egypt']

# %% [raw]
# df.city == 'A' | df.city == 'C'|df.city == 'D'
# c = ['A','C','D']
# df[df.city.isin(c)]

# %%
lst=[1,2]

# %%
samp[['Race']].isin(lst)
# Out:
#       Race
# ID
# 70   False
# 121  False
# 86   False
# 141  False
# 172  False
# 113  False
# 50   False
# 11    True
# 84   False
# 48   False
# 75   False
# 60   False
# 95   False
# 104  False
# 38   False
# 115  False
# 76   False
# 195  False
# 114  False
# 85   False
# 167  False
# 143  False
# 41   False
# 20    True
# 12    True
# 53   False
# 154  False
# 178  False
# 196  False
# 29    True
# ..     ...
# 119  False
# 13    True
# 51   False
# 26    True
# 36   False
# 135  False
# 59   False
# 78   False
# 64   False
# 63   False
# 79   False
# 193  False
# 92   False
# 160  False
# 32    True
# 23    True
# 158  False
# 25    True
# 188  False
# 52   False
# 124  False
# 175  False
# 184  False
# 30    True
# 179  False
# 31    True
# 145  False
# 187  False
# 118  False
# 137  False
#
# [200 rows x 1 columns]

# %%
matches = pd.read_csv('Datasets/matches.csv')

# %%
## filter for all the matches that played in - 'Hyderabad, Pune, Mumbai , Delhi , Kolkata'

# %%
matches.shape
# Out:
# (636, 18)

# %%
lst_cities = ['Hyderabad', 'Pune', 'Mumbai', 'Delhi', 'Kolkata']
# Out:
# ['Hyderabad', 'Pune', 'Mumbai', 'Delhi', 'Kolkata']

# %%
matches[matches.city.isin(lst_cities)].shape
# Out:
# (226, 18)

# %% [raw]
# Summary Statistics

# %%
samp.describe()
# Out:
#           Gender        Race         SEB      School        Prog       Total  \
# count  200.00000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.54500    3.430000    2.055000    1.160000    2.025000  261.905000
# std      0.49922    1.039472    0.724291    0.367526    0.690477   40.856114
# min      0.00000    1.000000    1.000000    1.000000    1.000000  165.000000
# 25%      0.00000    3.000000    2.000000    1.000000    2.000000  231.000000
# 50%      1.00000    4.000000    2.000000    1.000000    2.000000  265.000000
# 75%      1.00000    4.000000    3.000000    1.000000    2.250000  292.250000
# max      1.00000    4.000000    3.000000    2.000000    3.000000  343.000000
#
#              Read       Write       Math1       Math2         SST
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    52.230000   52.775000   52.645000   51.850000   52.405000
# std     10.252937    9.478586    9.368448    9.900891   10.735793
# min     28.000000   31.000000   33.000000   26.000000   26.000000
# 25%     44.000000   45.750000   45.000000   44.000000   46.000000
# 50%     50.000000   54.000000   52.000000   53.000000   52.000000
# 75%     60.000000   60.000000   59.000000   58.000000   61.000000
# max     76.000000   67.000000   75.000000   74.000000   71.000000

# %%
samp.Prog.value_counts()
# Out:
# 2    105
# 3     50
# 1     45
# Name: Prog, dtype: int64

# %%
samp[samp.Prog == 2].shape
# Out:
# (105, 11)

# %%
categorical = list(samp.columns)[0:5]

# %%
categorical
# Out:
# ['Gender', 'Race', 'SEB', 'School', 'Prog']

# %%
for i in categorical:
    samp[i]=samp[i].astype('category')

# %%
samp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 70 to 137
# Data columns (total 11 columns):
# Gender    200 non-null category
# Race      200 non-null category
# SEB       200 non-null category
# School    200 non-null category
# Prog      200 non-null category
# Total     200 non-null int64
# Read      200 non-null int64
# Write     200 non-null int64
# Math1     200 non-null int64
# Math2     200 non-null int64
# SST       200 non-null int64
# dtypes: category(5), int64(6)
# memory usage: 22.5 KB

# %%
samp.describe()
# Out:
#             Total        Read       Write       Math1       Math2         SST
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   261.905000   52.230000   52.775000   52.645000   51.850000   52.405000
# std     40.856114   10.252937    9.478586    9.368448    9.900891   10.735793
# min    165.000000   28.000000   31.000000   33.000000   26.000000   26.000000
# 25%    231.000000   44.000000   45.750000   45.000000   44.000000   46.000000
# 50%    265.000000   50.000000   54.000000   52.000000   53.000000   52.000000
# 75%    292.250000   60.000000   60.000000   59.000000   58.000000   61.000000
# max    343.000000   76.000000   67.000000   75.000000   74.000000   71.000000

# %%
samp[categorical].describe()
# Out:
#         Gender  Race  SEB  School  Prog
# count      200   200  200     200   200
# unique       2     4    3       2     3
# top          1     4    2       1     2
# freq       109   145   95     168   105

# %%
samp.Gender.value_counts()
# Out:
# 1    109
# 0     91
# Name: Gender, dtype: int64

# %%
samp.Race.mode()
# Out:
# 0    4
# Name: Race, dtype: category
# Categories (4, int64): [1, 2, 3, 4]

# %%
samp.Math1.quantile()
# Out:
# 52.0

# %%
samp.Math1.quantile(.25)
# Out:
# 45.0

# %%
samp.Math1.quantile(.75)
# Out:
# 59.0

# %%
samp.Math1.quantile(.5)
# Out:
# 52.0

# %%
samp.Math1.std()
# Out:
# 9.368447794077296

# %%
samp.Math1.var()
# Out:
# 87.76781407035176

# %%
# Cross Frequency Matrix

# %%
pd.crosstab(samp.Gender,samp.Prog,margins= True)
# Out:
# Prog     1    2   3  All
# Gender
# 0       21   47  23   91
# 1       24   58  27  109
# All     45  105  50  200

# %%
pd.crosstab([samp.Gender,samp.Prog],samp.Race, margins = True)
# Out:
# Race          1   2   3    4  All
# Gender Prog
# 0      1      1   1   2   17   21
#        2      6   2   3   36   47
#        3      6   0   2   15   23
# 1      1      3   3   3   15   24
#        2      5   4   6   43   58
#        3      3   1   4   19   27
# All          24  11  20  145  200

# %% [markdown]
# Melting and Pivoting the Data

# %%
patients=pd.read_csv('Datasets/Patient treatment trns.csv')

# %%
patients
# Out:
#   Patient Treatment      Spend
# 0      P1        T1   $422.00
# 1      P1        T2   $512.00
# 2      P2        T2   $541.00
# 3      P2        T3   $655.00
# 4      P2        T4   $592.00
# 5      P3        T1   $337.00
# 6      P3        T2   $537.00
# 7      P4        T3   $303.00
# 8      P4        T4   $744.00
# 9      P4        T5   $675.00

# %%
## Transpose Dataframe
patients.T
# Out:
#                    0          1          2          3          4          5  \
# Patient           P1         P1         P2         P2         P2         P3
# Treatment         T1         T2         T2         T3         T4         T1
# Spend       $422.00    $512.00    $541.00    $655.00    $592.00    $337.00
#
#                    6          7          8          9
# Patient           P3         P4         P4         P4
# Treatment         T2         T3         T4         T5
# Spend       $537.00    $303.00    $744.00    $675.00

# %%
#Transpose the data(Pivot)
patients_t = patients.pivot(index='Patient', 
                            columns='Treatment', 
                            values='Spend')

# %%
pd.crosstab(patients.Patient,patients.Treatment) ## fills in count  while pivot fills in values
# Out:
# Treatment  T1  T2  T3  T4  T5
# Patient
# P1          1   1   0   0   0
# P2          0   1   1   1   0
# P3          1   1   0   0   0
# P4          0   0   1   1   1

# %%
patients_t
# Out:
# Treatment         T1         T2         T3         T4         T5
# Patient
# P1          $422.00    $512.00        None       None       None
# P2              None   $541.00    $655.00    $592.00        None
# P3          $337.00    $537.00        None       None       None
# P4              None       None   $303.00    $744.00    $675.00

# %%
#Melt the data
patients_m = pd.melt(frame=patients_t.reset_index(), 
                     id_vars=['Patient'], 
                     value_vars=['T1', 'T2', 'T3', 'T4', 'T5']).dropna()

# %%
patients_m
# Out:
#    Patient Treatment      value
# 0       P1        T1   $422.00
# 2       P3        T1   $337.00
# 4       P1        T2   $512.00
# 5       P2        T2   $541.00
# 6       P3        T2   $537.00
# 9       P2        T3   $655.00
# 11      P4        T3   $303.00
# 13      P2        T4   $592.00
# 15      P4        T4   $744.00
# 19      P4        T5   $675.00

# %% [markdown]
# ### Create Excel like Summarised Pivot Table

# %% [raw]
# df.pivot_table(index=None, columns=None,
#                values=None,aggfunc='mean',
#                fill_value=None,
#                margins=False,
#                dropna=True,
#                margins_name='All')

# %%
matches.pivot_table(index='team1',
                    columns='team2',
                    values ='win_by_runs',
                    fill_value = '-'
                    ).head()
# Out:
# team2               Chennai Super Kings Deccan Chargers Delhi Daredevils  \
# team1
# Chennai Super Kings                   -          27.375          30.4545
# Deccan Chargers                    15.5               -            4.625
# Delhi Daredevils                    1.8               8                -
# Gujarat Lions                         -               -             0.25
# Kings XI Punjab                   9.375         8.66667              4.5
#
# team2               Gujarat Lions Kings XI Punjab Kochi Tuskers Kerala  \
# team1
# Chennai Super Kings             -         22.1111                  5.5
# Deccan Chargers                 -         12.5714                   55
# Delhi Daredevils                -             8.6                   19
# Gujarat Lions                   -               -                    -
# Kings XI Punjab             12.25               -                    -
#
# team2               Kolkata Knight Riders Mumbai Indians Pune Warriors  \
# team1
# Chennai Super Kings               10.6364           13.8         18.75
# Deccan Chargers                         0            8.2       10.3333
# Delhi Daredevils                  7.44444           16.8           7.5
# Gujarat Lions                           0              0             -
# Kings XI Punjab                    3.9375             17             0
#
# team2               Rajasthan Royals Rising Pune Supergiant  \
# team1
# Chennai Super Kings          15.8889                      -
# Deccan Chargers              7.57143                      -
# Delhi Daredevils             9.11111                     52
# Gujarat Lions                      -                      0
# Kings XI Punjab                 16.5                      0
#
# team2               Rising Pune Supergiants Royal Challengers Bangalore  \
# team1
# Chennai Super Kings                       -                        23.5
# Deccan Chargers                           -                      10.625
# Delhi Daredevils                        9.5                         6.4
# Gujarat Lions                             -                           0
# Kings XI Punjab                           0                     26.2857
#
# team2               Sunrisers Hyderabad
# team1
# Chennai Super Kings             40.6667
# Deccan Chargers                       -
# Delhi Daredevils                      1
# Gujarat Lions                         0
# Kings XI Punjab                      18

# %%
matches.loc[(matches.team1 == 'Chennai Super Kings') & (matches.team2 == 'Deccan Chargers'),'win_by_runs'].mean()
# Out:
# 27.375

# %% [markdown]
# ## counting the no. of matches played between each pair of teams

# %% [markdown]
# 1st pair of teams : Chennai Super Kings Deccan Chargers

# %%
matches.loc[(matches.team1 == 'Chennai Super Kings') & (matches.team2 == 'Deccan Chargers') ,'id'].count()
# Out:
# 8

# %%
matches.pivot_table(index='team1',
                    columns='team2',
                    values ='id', 
                    aggfunc = 'count',
                   fill_value = '-')
# Out:
# team2                       Chennai Super Kings Deccan Chargers  \
# team1
# Chennai Super Kings                           -               8
# Deccan Chargers                               2               -
# Delhi Daredevils                              5               3
# Gujarat Lions                                 -               -
# Kings XI Punjab                               8               3
# Kochi Tuskers Kerala                          -               -
# Kolkata Knight Riders                         5               7
# Mumbai Indians                               12               5
# Pune Warriors                                 2               1
# Rajasthan Royals                              8               2
# Rising Pune Supergiant                        -               -
# Rising Pune Supergiants                       -               -
# Royal Challengers Bangalore                   9               3
# Sunrisers Hyderabad                           3               -
#
# team2                       Delhi Daredevils Gujarat Lions Kings XI Punjab  \
# team1
# Chennai Super Kings                       11             -               9
# Deccan Chargers                            8             -               7
# Delhi Daredevils                           -             -              10
# Gujarat Lions                              4             -               -
# Kings XI Punjab                           10             4               -
# Kochi Tuskers Kerala                       -             -               1
# Kolkata Knight Riders                     10             3               5
# Mumbai Indians                            15             2               7
# Pune Warriors                              4             -               4
# Rajasthan Royals                           7             -               7
# Rising Pune Supergiant                     -             1               1
# Rising Pune Supergiants                    -             2               1
# Royal Challengers Bangalore                9             4              13
# Sunrisers Hyderabad                        6             -               6
#
# team2                       Kochi Tuskers Kerala Kolkata Knight Riders  \
# team1
# Chennai Super Kings                            2                    11
# Deccan Chargers                                1                     2
# Delhi Daredevils                               2                     9
# Gujarat Lions                                  -                     1
# Kings XI Punjab                                -                    16
# Kochi Tuskers Kerala                           -                     2
# Kolkata Knight Riders                          -                     -
# Mumbai Indians                                 1                     9
# Pune Warriors                                  -                     2
# Rajasthan Royals                               1                    14
# Rising Pune Supergiant                         -                     1
# Rising Pune Supergiants                        -                     2
# Royal Challengers Bangalore                    -                     4
# Sunrisers Hyderabad                            -                     7
#
# team2                       Mumbai Indians Pune Warriors Rajasthan Royals  \
# team1
# Chennai Super Kings                     10             4                9
# Deccan Chargers                          5             3                7
# Delhi Daredevils                         5             2                9
# Gujarat Lions                            2             -                -
# Kings XI Punjab                         13             2                8
# Kochi Tuskers Kerala                     -             1                1
# Kolkata Knight Riders                   12             3                1
# Mumbai Indians                           -             3               10
# Pune Warriors                            3             -                3
# Rajasthan Royals                         6             2                -
# Rising Pune Supergiant                   2             -                -
# Rising Pune Supergiants                  1             -                -
# Royal Challengers Bangalore             10             4                9
# Sunrisers Hyderabad                      6             2                7
#
# team2                       Rising Pune Supergiant Rising Pune Supergiants  \
# team1
# Chennai Super Kings                              -                       -
# Deccan Chargers                                  -                       -
# Delhi Daredevils                                 2                       2
# Gujarat Lions                                    1                       -
# Kings XI Punjab                                  1                       1
# Kochi Tuskers Kerala                             -                       -
# Kolkata Knight Riders                            1                       -
# Mumbai Indians                                   2                       1
# Pune Warriors                                    -                       -
# Rajasthan Royals                                 -                       -
# Rising Pune Supergiant                           -                       -
# Rising Pune Supergiants                          -                       -
# Royal Challengers Bangalore                      -                       1
# Sunrisers Hyderabad                              1                       2
#
# team2                       Royal Challengers Bangalore Sunrisers Hyderabad
# team1
# Chennai Super Kings                                  10                   3
# Deccan Chargers                                       8                   -
# Delhi Daredevils                                     10                   4
# Gujarat Lions                                         1                   5
# Kings XI Punjab                                       7                   4
# Kochi Tuskers Kerala                                  2                   -
# Kolkata Knight Riders                                16                   5
# Mumbai Indians                                       11                   4
# Pune Warriors                                         1                   -
# Rajasthan Royals                                      7                   -
# Rising Pune Supergiant                                2                   1
# Rising Pune Supergiants                               1                   -
# Royal Challengers Bangalore                           -                   4
# Sunrisers Hyderabad                                   6                   -

# %%
matches.pivot_table(index='team1',
                    columns='toss_decision',
                    values ='id', 
                    aggfunc = 'count',
                   fill_value = '-')
# Out:
# toss_decision                 bat  field
# team1
# Chennai Super Kings          44.0   33.0
# Deccan Chargers              24.0   19.0
# Delhi Daredevils             26.0   37.0
# Gujarat Lions                 1.0   13.0
# Kings XI Punjab              25.0   52.0
# Kochi Tuskers Kerala          3.0    4.0
# Kolkata Knight Riders        30.0   38.0
# Mumbai Indians               40.0   42.0
# Pune Warriors                11.0    9.0
# Rajasthan Royals             28.0   26.0
# Rising Pune Supergiant        NaN    8.0
# Rising Pune Supergiants       3.0    4.0
# Royal Challengers Bangalore  20.0   50.0
# Sunrisers Hyderabad          18.0   28.0

# %% [markdown]
# ## Handling String columns

# %%
strw ='Python'
strw[0]

# %%
#Splitting a column with .str
matches['new1']=matches.toss_decision.str[0]

# %%
matches.toss_decision.head(3)
# Out:
# 0    field
# 1    field
# 2    field
# Name: toss_decision, dtype: object

# %%
matches.toss_decision.apply(lambda x:x.upper()).head(3)
# Out:
# 0    FIELD
# 1    FIELD
# 2    FIELD
# Name: toss_decision, dtype: object

# %%
for i in range(len(matches)):
    matches.toss_decision[i] = matches.toss_decision[i].upper()

# %%
matches.toss_decision.str.upper().head(3)
# Out:
# 0    FIELD
# 1    FIELD
# 2    FIELD
# Name: toss_decision, dtype: object

# %%
matches.toss_decision[0]
# Out:
# 'field'

# %%
matches.toss_decision = matches.toss_decision.str.upper()

# %%
matches.toss_decision.value_counts()
# Out:
# FIELD    363
# BAT      273
# Name: toss_decision, dtype: int64

# %%
matches.new1.value_counts()

# %%
strw ='Nimisha'
strw[:4]
# Out:
# 'Nimi'

# %%
matches.city.str[:3].head(3)
# Out:
# 0    Hyd
# 1    Pun
# 2    Raj
# Name: city, dtype: object

# %%
matches.city.str[:3].head(3)
# Out:
# 0    Hyd
# 1    Pun
# 2    Raj
# Name: city, dtype: object

# %%
matches.city.str[2:5].head(3)
# Out:
# 0    der
# 1     ne
# 2    jko
# Name: city, dtype: object

# %%
string = 'My name * is * Nimisha'

# %%
type(string.split('*'))
# Out:
# list

# %%
matches['new2']=matches.team1.str.split()

# %%
matches.iloc[:2,[0,4,-1]].head()
# Out:
#    id                team1                    new2
# 0   1  Sunrisers Hyderabad  [Sunrisers, Hyderabad]
# 1   2       Mumbai Indians       [Mumbai, Indians]

# %%
matches.new2.str.get(0).head(2)
# Out:
# 0    Sunrisers
# 1       Mumbai
# Name: new2, dtype: object

# %%
matches['new2']=matches.new2.str.get(0)

# %%
matches.iloc[:2,[0,4,-1]].head()
# Out:
#    id                team1       new2
# 0   1  Sunrisers Hyderabad  Sunrisers
# 1   2       Mumbai Indians     Mumbai

# %%
#Concatenating multiple string columns

matches['teams12'] = matches['team1'] + " vs " + matches['team2']

# %%
#matches.teams12.str.rjust(50)

# %%
ser_1 = pd.Series([1,2,3,4,5,6], index= ['a','b','c','d','e','g'])
ser_2 = pd.Series([10,20,30,40,50,60],index = ['a','b','e','c','d','f'])

# %%
ser_1 * ser_2
# Out:
# a     10.0
# b     40.0
# c    120.0
# d    200.0
# e    150.0
# f      NaN
# g      NaN
# dtype: float64

# %%
ser_1.add(ser_2,fill_value = 0)
# Out:
# a    11.0
# b    22.0
# c    43.0
# d    54.0
# e    35.0
# f    60.0
# g     6.0
# dtype: float64

# %%
# ?matches.assign

# %%
samp_1 = samp.assign(percentage = samp.Total/5)

# %%
# Creating new data frame with old and new variables using 'Assign' 

matches_1=matches.assign(fname = 
                         matches.player_of_match.str.split().str.get(0))

# %%
matches_1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'new2', 'teams12', 'new_column', 'fname'],
#       dtype='object')

# %%
matches.new_column.head(3)
# Out:
# 0    blank
# 1    blank
# 2    blank
# Name: new_column, dtype: object

# %%
matches.head(2)
# Out:
#    id  season       city      date                team1  \
# 0   1    2017  Hyderabad  05/04/17  Sunrisers Hyderabad
# 1   2    2017       Pune  06/04/17       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3       new2
# 0  NJ Llong      NaN  Sunrisers
# 1    S Ravi      NaN     Mumbai

# %% [markdown]
# # SORTING DATAFRAMES

# %%
matches.sort_values(by='team1', ascending=True, inplace=True)

# %%
matches.team1.head()
# Out:
# 317    Chennai Super Kings
# 477    Chennai Super Kings
# 223    Chennai Super Kings
# 215    Chennai Super Kings
# 210    Chennai Super Kings
# Name: team1, dtype: object

# %%
samp_1.sort_values(by = 'Total', ascending=False, inplace = True)

# %%
samp_1.sort_values(by = ['Gender','Total','Math1'], ascending=[True,False,False], inplace = True)

# %%
samp_1.Gender.value_counts()
# Out:
# 1    109
# 0     91
# Name: Gender, dtype: int64

# %%
samp_1[['Gender','Total','Math1']][90:97]
# Out:
#     Gender  Total  Math1
# ID
# 108      0    180     41
# 100      1    339     71
# 180      1    334     69
# 61       1    332     60
# 57       1    330     72
# 39       1    327     67
# 88       1    327     64

# %%
matches.sort_values(by=['team1','win_by_runs'], 
                    ascending=[False,True],
                    inplace=True)

# %%
matches
# Out:
#       id  season            city      date                        team1  \
# 43    44    2017           Delhi  06/05/17               Mumbai Indians
# 619  620    2016       Bangalore  14/05/16  Royal Challengers Bangalore
# 59    60    2008       Bangalore  18/04/08        Kolkata Knight Riders
# 556  557    2015       Bangalore  06/05/15  Royal Challengers Bangalore
# 410  411    2013       Bangalore  23/04/13  Royal Challengers Bangalore
# 295  296    2011      Dharamsala  17/05/11              Kings XI Punjab
# 114  115    2008          Mumbai  30/05/08             Rajasthan Royals
# 182  183    2010           Delhi  17/03/10               Mumbai Indians
# 541  542    2015         Chennai  25/04/15          Chennai Super Kings
# 8      9    2017            Pune  11/04/17             Delhi Daredevils
# 464  465    2014       Abu Dhabi  21/04/14          Chennai Super Kings
# 121  122    2009  Port Elizabeth  20/04/09          Chennai Super Kings
# 131  132    2009  Port Elizabeth  27/04/09               Mumbai Indians
# 402  403    2013          Jaipur  17/04/13             Rajasthan Royals
# 403  404    2013           Delhi  18/04/13          Chennai Super Kings
# 379  380    2012         Chennai  25/05/12          Chennai Super Kings
# 279  280    2011       Bangalore  06/05/11  Royal Challengers Bangalore
# 612  613    2016   Visakhapatnam  08/05/16          Sunrisers Hyderabad
# 299  300    2011      Dharamsala  21/05/11              Deccan Chargers
# 26    27    2017         Kolkata  23/04/17        Kolkata Knight Riders
# 625  626    2016       Bangalore  18/05/16  Royal Challengers Bangalore
# 622  623    2016   Visakhapatnam  15/05/16               Mumbai Indians
# 143  144    2009     East London  04/05/09          Chennai Super Kings
# 144  145    2009          Durban  05/05/09             Rajasthan Royals
# 434  435    2013       Hyderabad  08/05/13          Chennai Super Kings
# 286  287    2011      Chandigarh  10/05/11              Kings XI Punjab
# 118  119    2009       Cape Town  18/04/09  Royal Challengers Bangalore
# 312  313    2012   Visakhapatnam  07/04/12          Chennai Super Kings
# 465  466    2014         Sharjah  22/04/14              Kings XI Punjab
# 573  574    2015            Pune  20/05/15  Royal Challengers Bangalore
# ..   ...     ...             ...       ...                          ...
# 147  148    2009       Centurion  07/05/09  Royal Challengers Bangalore
# 126  127    2009          Durban  24/04/09  Royal Challengers Bangalore
# 509  510    2014       Bangalore  24/05/14  Royal Challengers Bangalore
# 349  350    2012       Bangalore  02/05/12  Royal Challengers Bangalore
# 177  178    2010         Kolkata  14/03/10  Royal Challengers Bangalore
# 502  503    2014       Hyderabad  20/05/14  Royal Challengers Bangalore
# 103  104    2008       Bangalore  19/05/08  Royal Challengers Bangalore
# 491  492    2014       Bangalore  11/05/14  Royal Challengers Bangalore
# 627  628    2016          Raipur  20/05/16          Sunrisers Hyderabad
# 617  618    2016       Hyderabad  12/05/16          Sunrisers Hyderabad
# 571  572    2015       Hyderabad  17/05/15          Sunrisers Hyderabad
# 443  444    2013          Mumbai  13/05/13          Sunrisers Hyderabad
# 431  432    2013       Bangalore  09/04/13          Sunrisers Hyderabad
# 415  416    2013          Jaipur  27/04/13          Sunrisers Hyderabad
# 413  414    2013         Chennai  25/04/13          Sunrisers Hyderabad
# 56    57    2017       Bangalore  17/05/17          Sunrisers Hyderabad
# 38    39    2017           Delhi  02/05/17          Sunrisers Hyderabad
# 24    25    2017            Pune  22/04/17          Sunrisers Hyderabad
# 9     10    2017          Mumbai  12/04/17          Sunrisers Hyderabad
# 454  455    2013           Delhi  22/05/13          Sunrisers Hyderabad
# 460  461    2014       Abu Dhabi  18/04/14          Sunrisers Hyderabad
# 567  568    2015       Hyderabad  15/05/15          Sunrisers Hyderabad
# 583  584    2016       Hyderabad  16/04/16          Sunrisers Hyderabad
# 528  529    2015   Visakhapatnam  16/04/15          Sunrisers Hyderabad
# 499  500    2014       Hyderabad  18/05/14          Sunrisers Hyderabad
# 495  496    2014       Hyderabad  14/05/14          Sunrisers Hyderabad
# 492  493    2014       Hyderabad  12/05/14          Sunrisers Hyderabad
# 480  481    2014       Bangalore  04/05/14          Sunrisers Hyderabad
# 473  474    2014         Sharjah  27/04/14          Sunrisers Hyderabad
# 510  511    2014         Kolkata  24/05/14          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 43              Delhi Daredevils             Delhi Daredevils         field
# 619                Gujarat Lions                Gujarat Lions         field
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 556              Kings XI Punjab              Kings XI Punjab         field
# 410                Pune Warriors                Pune Warriors         field
# 295  Royal Challengers Bangalore              Kings XI Punjab           bat
# 114             Delhi Daredevils             Delhi Daredevils         field
# 182             Delhi Daredevils             Delhi Daredevils         field
# 541              Kings XI Punjab          Chennai Super Kings           bat
# 8         Rising Pune Supergiant       Rising Pune Supergiant         field
# 464             Delhi Daredevils          Chennai Super Kings           bat
# 121  Royal Challengers Bangalore          Chennai Super Kings           bat
# 131        Kolkata Knight Riders               Mumbai Indians           bat
# 402               Mumbai Indians             Rajasthan Royals           bat
# 403             Delhi Daredevils          Chennai Super Kings           bat
# 379             Delhi Daredevils             Delhi Daredevils         field
# 279              Kings XI Punjab              Kings XI Punjab         field
# 612               Mumbai Indians               Mumbai Indians         field
# 299              Kings XI Punjab              Kings XI Punjab         field
# 26   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 625              Kings XI Punjab              Kings XI Punjab         field
# 622             Delhi Daredevils             Delhi Daredevils         field
# 143              Deccan Chargers          Chennai Super Kings           bat
# 144              Kings XI Punjab              Kings XI Punjab         field
# 434          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 286               Mumbai Indians               Mumbai Indians         field
# 118             Rajasthan Royals  Royal Challengers Bangalore           bat
# 312              Deccan Chargers              Deccan Chargers         field
# 465          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 573             Rajasthan Royals  Royal Challengers Bangalore           bat
# ..                           ...                          ...           ...
# 147             Rajasthan Royals             Rajasthan Royals         field
# 126              Kings XI Punjab  Royal Challengers Bangalore           bat
# 509          Chennai Super Kings          Chennai Super Kings         field
# 349              Kings XI Punjab              Kings XI Punjab         field
# 177        Kolkata Knight Riders        Kolkata Knight Riders         field
# 502          Sunrisers Hyderabad  Royal Challengers Bangalore           bat
# 103             Delhi Daredevils             Delhi Daredevils         field
# 491             Rajasthan Royals  Royal Challengers Bangalore           bat
# 627             Delhi Daredevils             Delhi Daredevils         field
# 617             Delhi Daredevils             Delhi Daredevils         field
# 571               Mumbai Indians          Sunrisers Hyderabad           bat
# 443               Mumbai Indians          Sunrisers Hyderabad           bat
# 431  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
# 415             Rajasthan Royals          Sunrisers Hyderabad           bat
# 413          Chennai Super Kings          Sunrisers Hyderabad           bat
# 56         Kolkata Knight Riders        Kolkata Knight Riders         field
# 38              Delhi Daredevils             Delhi Daredevils         field
# 24        Rising Pune Supergiant       Rising Pune Supergiant         field
# 9                 Mumbai Indians               Mumbai Indians         field
# 454             Rajasthan Royals          Sunrisers Hyderabad           bat
# 460             Rajasthan Royals             Rajasthan Royals         field
# 567  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
# 583        Kolkata Knight Riders          Sunrisers Hyderabad           bat
# 528             Rajasthan Royals             Rajasthan Royals         field
# 499        Kolkata Knight Riders          Sunrisers Hyderabad           bat
# 495              Kings XI Punjab              Kings XI Punjab         field
# 492               Mumbai Indians          Sunrisers Hyderabad           bat
# 480  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 473          Chennai Super Kings          Sunrisers Hyderabad           bat
# 510        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#      result  dl_applied                       winner  win_by_runs  \
# 43   normal           0               Mumbai Indians          146
# 619  normal           0  Royal Challengers Bangalore          144
# 59   normal           0        Kolkata Knight Riders          140
# 556  normal           0  Royal Challengers Bangalore          138
# 410  normal           0  Royal Challengers Bangalore          130
# 295  normal           0              Kings XI Punjab          111
# 114  normal           0             Rajasthan Royals          105
# 182  normal           0               Mumbai Indians           98
# 541  normal           0          Chennai Super Kings           97
# 8    normal           0             Delhi Daredevils           97
# 464  normal           0          Chennai Super Kings           93
# 121  normal           0          Chennai Super Kings           92
# 131  normal           0               Mumbai Indians           92
# 402  normal           0             Rajasthan Royals           87
# 403  normal           0          Chennai Super Kings           86
# 379  normal           0          Chennai Super Kings           86
# 279  normal           0  Royal Challengers Bangalore           85
# 612  normal           0          Sunrisers Hyderabad           85
# 299  normal           0              Deccan Chargers           82
# 26   normal           0        Kolkata Knight Riders           82
# 625  normal           1  Royal Challengers Bangalore           82
# 622  normal           0               Mumbai Indians           80
# 143  normal           0          Chennai Super Kings           78
# 144  normal           0             Rajasthan Royals           78
# 434  normal           0          Chennai Super Kings           77
# 286  normal           0              Kings XI Punjab           76
# 118  normal           0  Royal Challengers Bangalore           75
# 312  normal           0          Chennai Super Kings           74
# 465  normal           0              Kings XI Punjab           72
# 573  normal           0  Royal Challengers Bangalore           71
# ..      ...         ...                          ...          ...
# 147  normal           0             Rajasthan Royals            0
# 126  normal           0              Kings XI Punjab            0
# 509  normal           0          Chennai Super Kings            0
# 349  normal           0              Kings XI Punjab            0
# 177  normal           0        Kolkata Knight Riders            0
# 502  normal           0          Sunrisers Hyderabad            0
# 103  normal           0             Delhi Daredevils            0
# 491  normal           0             Rajasthan Royals            0
# 627  normal           0             Delhi Daredevils            0
# 617  normal           0             Delhi Daredevils            0
# 571  normal           0               Mumbai Indians            0
# 443  normal           0               Mumbai Indians            0
# 431  normal           0  Royal Challengers Bangalore            0
# 415  normal           0             Rajasthan Royals            0
# 413  normal           0          Chennai Super Kings            0
# 56   normal           1        Kolkata Knight Riders            0
# 38   normal           0             Delhi Daredevils            0
# 24   normal           0       Rising Pune Supergiant            0
# 9    normal           0               Mumbai Indians            0
# 454  normal           0             Rajasthan Royals            0
# 460  normal           0             Rajasthan Royals            0
# 567  normal           1  Royal Challengers Bangalore            0
# 583  normal           0        Kolkata Knight Riders            0
# 528  normal           0             Rajasthan Royals            0
# 499  normal           0        Kolkata Knight Riders            0
# 495  normal           0              Kings XI Punjab            0
# 492  normal           0               Mumbai Indians            0
# 480  normal           0  Royal Challengers Bangalore            0
# 473  normal           0          Chennai Super Kings            0
# 510  normal           0        Kolkata Knight Riders            0
#
#      win_by_wickets  player_of_match  \
# 43                0      LMP Simmons
# 619               0   AB de Villiers
# 59                0      BB McCullum
# 556               0         CH Gayle
# 410               0         CH Gayle
# 295               0     AC Gilchrist
# 114               0        SR Watson
# 182               0     SR Tendulkar
# 541               0      BB McCullum
# 8                 0        SV Samson
# 464               0         SK Raina
# 121               0   M Muralitharan
# 131               0     SR Tendulkar
# 402               0        AM Rahane
# 403               0       MEK Hussey
# 379               0          M Vijay
# 279               0         CH Gayle
# 612               0          A Nehra
# 299               0         S Dhawan
# 26                0  NM Coulter-Nile
# 625               0          V Kohli
# 622               0        KH Pandya
# 143               0         MS Dhoni
# 144               0         GC Smith
# 434               0         SK Raina
# 286               0         BA Bhatt
# 118               0         R Dravid
# 312               0        RA Jadeja
# 465               0       GJ Maxwell
# 573               0   AB de Villiers
# ..              ...              ...
# 147               7          A Singh
# 126               7        RS Bopara
# 509               8         MS Dhoni
# 349               4    Azhar Mahmood
# 177               7        MK Tiwary
# 502               7        DA Warner
# 103               5       SP Goswami
# 491               5      JP Faulkner
# 627               6          KK Nair
# 617               7        CH Morris
# 571               9   MJ McClenaghan
# 443               7       KA Pollard
# 431               7          V Kohli
# 415               8      JP Faulkner
# 413               5         MS Dhoni
# 56                7  NM Coulter-Nile
# 38                6   Mohammed Shami
# 24                6         MS Dhoni
# 9                 4        JJ Bumrah
# 454               4         BJ Hodge
# 460               4        AM Rahane
# 567               6          V Kohli
# 583               8        G Gambhir
# 528               6        AM Rahane
# 499               7         UT Yadav
# 495               6          WP Saha
# 492               7        AT Rayudu
# 480               4   AB de Villiers
# 473               5         DR Smith
# 510               4        YK Pathan
#
#                                                  venue                umpire1  \
# 43                                    Feroz Shah Kotla            Nitin Menon
# 619                              M Chinnaswamy Stadium            AY Dandekar
# 59                               M Chinnaswamy Stadium              Asad Rauf
# 556                              M Chinnaswamy Stadium         RK Illingworth
# 410                              M Chinnaswamy Stadium              Aleem Dar
# 295       Himachal Pradesh Cricket Association Stadium              Asad Rauf
# 114                                   Wankhede Stadium              BF Bowden
# 182                                   Feroz Shah Kotla            BR Doctrove
# 541                    MA Chidambaram Stadium, Chepauk              JD Cloete
# 8              Maharashtra Cricket Association Stadium            AY Dandekar
# 464                               Sheikh Zayed Stadium         RK Illingworth
# 121                                   St George's Park             BG Jerling
# 131                                   St George's Park             BG Jerling
# 402                             Sawai Mansingh Stadium              Aleem Dar
# 403                                   Feroz Shah Kotla              M Erasmus
# 379                    MA Chidambaram Stadium, Chepauk            BR Doctrove
# 279                              M Chinnaswamy Stadium              Aleem Dar
# 612  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...                 S Ravi
# 299       Himachal Pradesh Cricket Association Stadium              Asad Rauf
# 26                                        Eden Gardens            CB Gaffaney
# 625                              M Chinnaswamy Stadium  KN Ananthapadmanabhan
# 622  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...            Nitin Menon
# 143                                       Buffalo Park            BR Doctrove
# 144                                          Kingsmead              SS Hazare
# 434          Rajiv Gandhi International Stadium, Uppal                  S Das
# 286         Punjab Cricket Association Stadium, Mohali            SK Tarapore
# 118                                           Newlands            BR Doctrove
# 312  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              JD Cloete
# 465                            Sharjah Cricket Stadium              M Erasmus
# 573            Maharashtra Cricket Association Stadium           AK Chaudhary
# ..                                                 ...                    ...
# 147                                    SuperSport Park            K Hariharan
# 126                                          Kingsmead            BR Doctrove
# 509                              M Chinnaswamy Stadium           AK Chaudhary
# 349                              M Chinnaswamy Stadium              BF Bowden
# 177                                       Eden Gardens        HDPK Dharmasena
# 502          Rajiv Gandhi International Stadium, Uppal           AK Chaudhary
# 103                              M Chinnaswamy Stadium               SJ Davis
# 491                              M Chinnaswamy Stadium                 S Ravi
# 627   Shaheed Veer Narayan Singh International Stadium         A Nand Kishore
# 617          Rajiv Gandhi International Stadium, Uppal             K Bharatan
# 571          Rajiv Gandhi International Stadium, Uppal            CB Gaffaney
# 443                                   Wankhede Stadium           AK Chaudhary
# 431                              M Chinnaswamy Stadium                 S Ravi
# 415                             Sawai Mansingh Stadium            VA Kulkarni
# 413                    MA Chidambaram Stadium, Chepauk              Aleem Dar
# 56                               M Chinnaswamy Stadium           AK Chaudhary
# 38                                    Feroz Shah Kotla               YC Barde
# 24             Maharashtra Cricket Association Stadium            AY Dandekar
# 9                                     Wankhede Stadium            Nitin Menon
# 454                                   Feroz Shah Kotla                 S Ravi
# 460                               Sheikh Zayed Stadium              BF Bowden
# 567          Rajiv Gandhi International Stadium, Uppal           AK Chaudhary
# 583          Rajiv Gandhi International Stadium, Uppal           AK Chaudhary
# 528  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              PG Pathak
# 499          Rajiv Gandhi International Stadium, Uppal               NJ Llong
# 495          Rajiv Gandhi International Stadium, Uppal            VA Kulkarni
# 492          Rajiv Gandhi International Stadium, Uppal        HDPK Dharmasena
# 480                              M Chinnaswamy Stadium        HDPK Dharmasena
# 473                            Sharjah Cricket Stadium           AK Chaudhary
# 510                                       Eden Gardens           RM Deshpande
#
#              umpire2  umpire3       new2  \
# 43         CK Nandan      NaN     Mumbai
# 619        VK Sharma      NaN      Royal
# 59       RE Koertzen      NaN    Kolkata
# 556      VA Kulkarni      NaN      Royal
# 410    C Shamshuddin      NaN      Royal
# 295        AM Saheba      NaN      Kings
# 114      RE Koertzen      NaN  Rajasthan
# 182      SK Tarapore      NaN     Mumbai
# 541    C Shamshuddin      NaN    Chennai
# 8             S Ravi      NaN      Delhi
# 464    C Shamshuddin      NaN    Chennai
# 121       SJA Taufel      NaN    Chennai
# 131        RB Tiffin      NaN     Mumbai
# 402    C Shamshuddin      NaN  Rajasthan
# 403      VA Kulkarni      NaN    Chennai
# 379       SJA Taufel      NaN    Chennai
# 279        RB Tiffin      NaN      Royal
# 612    C Shamshuddin      NaN  Sunrisers
# 299        AM Saheba      NaN     Deccan
# 26         CK Nandan      NaN    Kolkata
# 625        M Erasmus      NaN      Royal
# 622        CK Nandan      NaN     Mumbai
# 143        M Erasmus      NaN    Chennai
# 144        IL Howell      NaN  Rajasthan
# 434         NJ Llong      NaN    Chennai
# 286        RJ Tucker      NaN      Kings
# 118        RB Tiffin      NaN      Royal
# 312  HDPK Dharmasena      NaN    Chennai
# 465           S Ravi      NaN      Kings
# 573    C Shamshuddin      NaN      Royal
# ..               ...      ...        ...
# 147        DJ Harper      NaN      Royal
# 126   TH Wijewardene      NaN      Royal
# 509         NJ Llong      NaN      Royal
# 349    C Shamshuddin      NaN      Royal
# 177        AM Saheba      NaN      Royal
# 502         NJ Llong      NaN      Royal
# 103   GA Pratapkumar      NaN      Royal
# 491        RJ Tucker      NaN      Royal
# 627     BNJ Oxenford      NaN  Sunrisers
# 617        M Erasmus      NaN  Sunrisers
# 571        K Srinath      NaN  Sunrisers
# 443       SJA Taufel      NaN  Sunrisers
# 431       SJA Taufel      NaN  Sunrisers
# 415        K Srinath      NaN  Sunrisers
# 413            S Das      NaN  Sunrisers
# 56       Nitin Menon      NaN  Sunrisers
# 38       Nitin Menon      NaN  Sunrisers
# 24        A Deshmukh      NaN  Sunrisers
# 9          CK Nandan      NaN  Sunrisers
# 454        RJ Tucker      NaN  Sunrisers
# 460   RK Illingworth      NaN  Sunrisers
# 567  HDPK Dharmasena      NaN  Sunrisers
# 583        CK Nandan      NaN  Sunrisers
# 528           S Ravi      NaN  Sunrisers
# 499        CK Nandan      NaN  Sunrisers
# 495        PG Pathak      NaN  Sunrisers
# 492      VA Kulkarni      NaN  Sunrisers
# 480      VA Kulkarni      NaN  Sunrisers
# 473      VA Kulkarni      NaN  Sunrisers
# 510     BNJ Oxenford      NaN  Sunrisers
#
#                                                teams12
# 43                  Mumbai Indians vs Delhi Daredevils
# 619       Royal Challengers Bangalore vs Gujarat Lions
# 59   Kolkata Knight Riders vs Royal Challengers Ban...
# 556     Royal Challengers Bangalore vs Kings XI Punjab
# 410       Royal Challengers Bangalore vs Pune Warriors
# 295     Kings XI Punjab vs Royal Challengers Bangalore
# 114               Rajasthan Royals vs Delhi Daredevils
# 182                 Mumbai Indians vs Delhi Daredevils
# 541             Chennai Super Kings vs Kings XI Punjab
# 8           Delhi Daredevils vs Rising Pune Supergiant
# 464            Chennai Super Kings vs Delhi Daredevils
# 121  Chennai Super Kings vs Royal Challengers Banga...
# 131            Mumbai Indians vs Kolkata Knight Riders
# 402                 Rajasthan Royals vs Mumbai Indians
# 403            Chennai Super Kings vs Delhi Daredevils
# 379            Chennai Super Kings vs Delhi Daredevils
# 279     Royal Challengers Bangalore vs Kings XI Punjab
# 612              Sunrisers Hyderabad vs Mumbai Indians
# 299                 Deccan Chargers vs Kings XI Punjab
# 26   Kolkata Knight Riders vs Royal Challengers Ban...
# 625     Royal Challengers Bangalore vs Kings XI Punjab
# 622                 Mumbai Indians vs Delhi Daredevils
# 143             Chennai Super Kings vs Deccan Chargers
# 144                Rajasthan Royals vs Kings XI Punjab
# 434         Chennai Super Kings vs Sunrisers Hyderabad
# 286                  Kings XI Punjab vs Mumbai Indians
# 118    Royal Challengers Bangalore vs Rajasthan Royals
# 312             Chennai Super Kings vs Deccan Chargers
# 465             Kings XI Punjab vs Sunrisers Hyderabad
# 573    Royal Challengers Bangalore vs Rajasthan Royals
# ..                                                 ...
# 147    Royal Challengers Bangalore vs Rajasthan Royals
# 126     Royal Challengers Bangalore vs Kings XI Punjab
# 509  Royal Challengers Bangalore vs Chennai Super K...
# 349     Royal Challengers Bangalore vs Kings XI Punjab
# 177  Royal Challengers Bangalore vs Kolkata Knight ...
# 502  Royal Challengers Bangalore vs Sunrisers Hyder...
# 103    Royal Challengers Bangalore vs Delhi Daredevils
# 491    Royal Challengers Bangalore vs Rajasthan Royals
# 627            Sunrisers Hyderabad vs Delhi Daredevils
# 617            Sunrisers Hyderabad vs Delhi Daredevils
# 571              Sunrisers Hyderabad vs Mumbai Indians
# 443              Sunrisers Hyderabad vs Mumbai Indians
# 431  Sunrisers Hyderabad vs Royal Challengers Banga...
# 415            Sunrisers Hyderabad vs Rajasthan Royals
# 413         Sunrisers Hyderabad vs Chennai Super Kings
# 56        Sunrisers Hyderabad vs Kolkata Knight Riders
# 38             Sunrisers Hyderabad vs Delhi Daredevils
# 24       Sunrisers Hyderabad vs Rising Pune Supergiant
# 9                Sunrisers Hyderabad vs Mumbai Indians
# 454            Sunrisers Hyderabad vs Rajasthan Royals
# 460            Sunrisers Hyderabad vs Rajasthan Royals
# 567  Sunrisers Hyderabad vs Royal Challengers Banga...
# 583       Sunrisers Hyderabad vs Kolkata Knight Riders
# 528            Sunrisers Hyderabad vs Rajasthan Royals
# 499       Sunrisers Hyderabad vs Kolkata Knight Riders
# 495             Sunrisers Hyderabad vs Kings XI Punjab
# 492              Sunrisers Hyderabad vs Mumbai Indians
# 480  Sunrisers Hyderabad vs Royal Challengers Banga...
# 473         Sunrisers Hyderabad vs Chennai Super Kings
# 510       Sunrisers Hyderabad vs Kolkata Knight Riders
#
# [636 rows x 20 columns]

# %%
## storing a dataframe in a format on the machine

# %%
matches.to_csv('file.csv')

# %%
select col1,col2,col3
from table
where col4 > 50
table[col1,col2,col3,col4,col5]

# %%
samp.loc[samp.Write > 50,[columns]]

# %% [raw]
# GroupBy:
#
# .size() method, which returns the count of elements in each group.
#
# Aggregate Functions:
#
# count, sum, mean, median, std, var, first, last, min, max
# methods like .describe apply to these objects
#
# GroupBy Object methods: .agg() .transform(), and .apply()

# %%
grouped = samp.groupby('Gender')

# %% [raw]
# grouped.get_group(group) ---> return the filtered data

# %%
grouped.get_group(1)
# Out:
#      Math1  Math2 Prog Race  Read SEB  SST School  Total  Write
# ID
# 45      41     29    3    3    34   1   26      1    165     35
# 51      42     31    1    3    42   3   39      1    190     36
# 89      40     51    3    4    35   1   33      1    194     35
# 2       33     42    3    1    39   2   41      1    196     41
# 1       40     39    3    1    34   1   41      1    198     44
# 69      40     40    3    4    44   1   31      1    199     44
# 106     37     42    3    4    36   2   41      1    200     44
# 109     42     42    1    4    42   2   41      1    206     39
# 145     38     36    3    4    42   2   46      1    208     46
# 25      42     42    1    2    47   2   36      1    211     44
# 19      43     44    1    1    28   1   51      1    212     46
# 6       46     40    2    1    47   1   41      1    215     41
# 111     39     47    1    4    39   1   36      1    215     54
# 43      43     42    2    3    47   1   46      1    215     37
# 47      49     33    2    3    47   1   41      1    216     46
# 37      40     39    3    3    41   1   51      1    218     47
# 46      44     34    2    3    45   1   41      1    219     55
# 124     41     42    3    4    42   1   41      1    220     54
# 36      44     35    1    3    44   1   51      1    223     49
# 4       41     39    2    1    44   1   51      1    225     50
# 175     42     50    1    4    36   3   41      2    226     57
# 30      42     34    2    2    41   3   51      1    227     59
# 8       52     44    2    1    39   1   48      1    227     44
# 142     52     39    3    4    47   2   51      1    231     42
# 193     48     39    2    4    44   2   51      2    231     49
# 129     46     47    1    4    44   1   51      1    232     44
# 44      45     34    3    3    47   1   46      1    234     62
# 182     43     44    2    4    44   2   51      2    234     52
# 105     45     44    2    4    50   2   56      1    236     41
# 72      47     47    3    4    42   2   46      1    236     54
# ..     ...    ...  ...  ...   ...  ..  ...    ...    ...    ...
# 122     58     53    2    4    52   2   66      1    288     59
# 99      56     66    1    4    47   3   61      1    289     59
# 26      62     61    2    2    60   3   51      1    293     59
# 131     57     46    2    4    65   3   66      1    293     59
# 96      61     58    2    4    65   3   56      1    294     54
# 118     58     58    1    4    55   2   61      1    294     62
# 101     67     50    2    4    60   3   56      1    295     62
# 188     56     55    2    4    63   3   61      2    297     62
# 71      56     58    1    4    57   2   66      1    299     62
# 92      57     63    1    4    52   3   61      1    300     67
# 121     53     63    3    4    68   2   61      1    304     59
# 33      72     54    2    2    57   1   56      1    304     65
# 32      66     66    3    2    50   3   56      1    305     67
# 125     58     59    2    4    68   1   56      1    306     65
# 137     65     53    2    4    63   3   61      1    307     65
# 135     65     54    2    4    63   1   66      1    308     60
# 34      57     55    2    1    73   3   66      2    312     61
# 161     72     61    2    4    57   1   61      1    313     62
# 139     61     55    2    4    68   2   71      1    314     59
# 194     69     61    2    4    63   3   61      2    317     63
# 59      63     55    2    4    65   2   71      1    321     67
# 23      64     58    2    2    65   1   71      1    323     65
# 82      65     69    2    4    68   3   61      1    325     62
# 93      62     58    2    4    73   3   66      1    326     67
# 88      64     69    2    4    68   3   66      1    327     60
# 39      67     61    2    3    66   3   66      1    327     67
# 57      72     66    2    4    71   2   56      1    330     65
# 61      60     67    2    4    76   3   66      1    332     63
# 180     69     58    2    4    71   3   71      2    334     65
# 100     71     69    2    4    63   3   71      1    339     65
#
# [109 rows x 10 columns]

# %%
grouped.describe().T
# Out:
# Gender                0           1
# Math1 count   91.000000  109.000000
#       mean    52.945055   52.394495
#       std      9.664784    9.151015
#       min     35.000000   33.000000
#       25%     45.000000   45.000000
#       50%     52.000000   53.000000
#       75%     59.500000   58.000000
#       max     75.000000   72.000000
# Math2 count   91.000000  109.000000
#       mean    53.230769   50.697248
#       std     10.732171    9.038503
#       min     26.000000   29.000000
#       25%     46.000000   44.000000
#       50%     55.000000   50.000000
#       75%     61.000000   58.000000
#       max     74.000000   69.000000
# Read  count   91.000000  109.000000
#       mean    52.824176   51.733945
#       std     10.506710   10.057835
#       min     31.000000   28.000000
#       25%     44.500000   44.000000
#       50%     52.000000   50.000000
#       75%     63.000000   57.000000
#       max     76.000000   76.000000
# SST   count   91.000000  109.000000
#       mean    51.791209   52.917431
#       std     11.333840   10.234409
#       min     26.000000   26.000000
#       25%     46.000000   46.000000
#       50%     51.000000   56.000000
#       75%     61.000000   61.000000
#       max     71.000000   71.000000
# Total count   91.000000  109.000000
#       mean   260.912088  262.733945
#       std     43.417520   38.772041
#       min    180.000000  165.000000
#       25%    224.500000  234.000000
#       50%    265.000000  264.000000
#       75%    291.500000  293.000000
#       max    343.000000  339.000000
# Write count   91.000000  109.000000
#       mean    50.120879   54.990826
#       std     10.305161    8.133715
#       min     31.000000   35.000000
#       25%     41.000000   50.000000
#       50%     52.000000   57.000000
#       75%     59.000000   62.000000
#       max     67.000000   67.000000

# %%
samp.describe()
# Out:
#             Total        Read       Write       Math1       Math2         SST
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   261.905000   52.230000   52.775000   52.645000   51.850000   52.405000
# std     40.856114   10.252937    9.478586    9.368448    9.900891   10.735793
# min    165.000000   28.000000   31.000000   33.000000   26.000000   26.000000
# 25%    231.000000   44.000000   45.750000   45.000000   44.000000   46.000000
# 50%    265.000000   50.000000   54.000000   52.000000   53.000000   52.000000
# 75%    292.250000   60.000000   60.000000   59.000000   58.000000   61.000000
# max    343.000000   76.000000   67.000000   75.000000   74.000000   71.000000

# %%
grouped.agg('mean')
# Out:
#              Total       Read      Write      Math1      Math2        SST
# Gender
# 0       260.912088  52.824176  50.120879  52.945055  53.230769  51.791209
# 1       262.733945  51.733945  54.990826  52.394495  50.697248  52.917431

# %%
grouped.mean()
# Out:
#              Total       Read      Write      Math1      Math2        SST
# Gender
# 0       260.912088  52.824176  50.120879  52.945055  53.230769  51.791209
# 1       262.733945  51.733945  54.990826  52.394495  50.697248  52.917431

# %%
samp.groupby('School').mean()
# Out:
#              Total       Read     Write      Math1      Math2        SST
# School
# 1       259.863095  51.845238  52.25000  52.244048  51.571429  51.952381
# 2       272.625000  54.250000  55.53125  54.750000  53.312500  54.781250

# %%
samp.groupby(['School','Gender']).mean()
# Out:
#                     Total       Read      Write      Math1      Math2  \
# School Gender
# 1      0       257.909091  52.350649  49.363636  52.311688  52.857143
#        1       261.516484  51.417582  54.692308  52.186813  50.483516
# 2      0       277.428571  55.428571  54.285714  56.428571  55.285714
#        1       268.888889  53.333333  56.500000  53.444444  51.777778
#
#                      SST
# School Gender
# 1      0       51.025974
#        1       52.736264
# 2      0       56.000000
#        1       53.833333

# %%
#file_name.groupby([])[[list of variables]]. aggFunct()
#grpd = samp.groupby(['School','Gender'])
#obj = grpd[['Math1','SST']]
#obj.mean()
samp.groupby(['School','Gender'])[['Math1','SST']].mean()
# Out:
#                    Math1        SST
# School Gender
# 1      0       52.311688  51.025974
#        1       52.186813  52.736264
# 2      0       56.428571  56.000000
#        1       53.444444  53.833333

# %% [markdown]
# Multiple Aggregation

# %%
samp.groupby(['School','Gender'])[['Math1','SST']].agg(['mean','std','var','sum'])
# Out:
#                    Math1                                   SST             \
#                     mean       std        var   sum       mean        std
# School Gender
# 1      0       52.311688  9.565921  91.506835  4028  51.025974  11.509692
#        1       52.186813  9.366503  87.731380  4749  52.736264  10.375008
# 2      0       56.428571  9.811408  96.263736   790  56.000000   9.607689
#        1       53.444444  8.132883  66.143791   962  53.833333   9.721111
#
#
#                       var   sum
# School Gender
# 1      0       132.473001  3929
#        1       107.640781  4799
# 2      0        92.307692   784
#        1        94.500000   969

# %% [raw]
# Custom Aggregation

# %%
def data_range(series):
    return series.max() - series.min()

# %%
samp.groupby(['School','Gender'])[['Math1','SST']].agg(data_range)
# Out:
#                Math1  SST
# School Gender
# 1      0          40   45
#        1          39   45
# 2      0          34   30
#        1          27   40

# %% [raw]
# Custom Aggregation : Dictionaries

# %%
samp.groupby(['School','Gender']).agg({'Read':['mean','std'],
                                      'Math1':'median',
                                     'Prog':'count'})
# Out:
#                     Read             Math1  Prog
#                     mean        std median count
# School Gender
# 1      0       52.350649  10.811502   51.0    77
#        1       51.417582  10.122654   53.0    91
# 2      0       55.428571   8.500808   56.0    14
#        1       53.333333   9.845871   52.5    18

# %%
# ?grouped.agg

# %% [markdown]
# Using regular
# expressions to
# clean strings

# %% [raw]
# 12345678901              \d*
# $12345678901             \$\d*
# $12345678901.42          \$\d*\.\d*
# $12345678901.42          \$\d*\.\d{2}
# 123-456-7890             \d{3}-\d{3}-\d{4}
# Australia                [A-Z]\w*
#
#
# The regular expression module in python is re. When performing pattern matching on data,
# since the pattern will be used for a match across multiple rows,
# it's better to compile the pattern first using re.compile(), and then use the compiled
# pattern to match values.
#
# Do visit https://docs.python.org/2/library/re.html for more information

# %%
import re

# %%
#Write a pattern that will 
#find all the numbers in the following string: 'It is a big 198 lines' program; need to reduce to less than 50'

match = re.findall('\d+', "It is a big 198 lines' program; need to reduce to less than 50")

match
# Out:
# ['198', '50']

# %% [raw]
# After compilation, methods can be applied:
#
# split,
# findall  - returns all matches,
# match  - checks only the beginning of the string,
# search  - returns the first occurrence
# sub  - returns a new string with occurrences of the pattern replaced with the supplied string

# %%
data = {'raw': ['Arizona 1 2014-12-23       3242.0',
                'Iowa 1 2010-02-23       3453.7',
                'Oregon 0 2014-06-20       2123.0',
                'Maryland 0 2014-03-14       1123.6',
                'Florida 1 2013-01-15       2134.0',
                'Georgia 0 2012-07-14       2345.6']}
df = pd.DataFrame(data, columns = ['raw'])
df
# Out:
#                                   raw
# 0   Arizona 1 2014-12-23       3242.0
# 1      Iowa 1 2010-02-23       3453.7
# 2    Oregon 0 2014-06-20       2123.0
# 3  Maryland 0 2014-03-14       1123.6
# 4   Florida 1 2013-01-15       2134.0
# 5   Georgia 0 2012-07-14       2345.6

# %%
df['raw'].str.contains('[0-9]',regex=True)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# Name: raw, dtype: bool

# %%
# In the column 'raw', extract xxxx-xx-xx in the strings
df['date'] = df['raw'].str.extract('(....-..-..)', expand=True)
df
# Out:
#                                   raw        date
# 0   Arizona 1 2014-12-23       3242.0  2014-12-23
# 1      Iowa 1 2010-02-23       3453.7  2010-02-23
# 2    Oregon 0 2014-06-20       2123.0  2014-06-20
# 3  Maryland 0 2014-03-14       1123.6  2014-03-14
# 4   Florida 1 2013-01-15       2134.0  2013-01-15
# 5   Georgia 0 2012-07-14       2345.6  2012-07-14

# %%
# In the column 'raw', extract single digit in the strings
df['female'] = df['raw'].str.extract('(\d)', expand=True)
df

# %%
# In the column 'raw', extract ####.## in the strings
df['score'] = df['raw'].str.extract('(\d\d\d\d\.\d)', expand=True)
df

# %%
# In the column 'raw', extract the word in the strings
df['state'] = df['raw'].str.extract('([A-Z]\w{1,})', expand=True)
df

# %% [markdown]
# ### Custom Function to Clean the data

# %%
def recode_sex(sex_value):
    if sex_value == 0:
        return 'Male'
    
    elif sex_value == 1:
        return 'Female'      
    else:
        return 'NA'

# %%
samp.head()
# Out:
#     Gender Race SEB School Prog  Total  Read  Write  Math1  Math2  SST
# ID
# 45       1    3   1      1    3    165    34     35     41     29   26
# 108      0    4   2      1    1    180    34     33     41     36   36
# 67       0    4   1      1    3    181    37     37     42     33   32
# 133      0    4   2      1    3    186    50     31     40     34   31
# 53       0    3   2      1    3    187    34     37     46     39   31

# %%
sex = []
for i in range(0,len(samp)):
    val = samp.Gender.iloc[i]
    sex.append(recode_sex(val))
samp['s_loop'] = sex

# %%
samp['Sex']=samp.Gender.apply(recode_sex)

# %%
samp.head()
# Out:
#     Gender Race SEB School Prog  Total  Read  Write  Math1  Math2  SST  \
# ID
# 45       1    3   1      1    3    165    34     35     41     29   26
# 108      0    4   2      1    1    180    34     33     41     36   36
# 67       0    4   1      1    3    181    37     37     42     33   32
# 133      0    4   2      1    3    186    50     31     40     34   31
# 53       0    3   2      1    3    187    34     37     46     39   31
#
#      s_loop     Sex
# ID
# 45   Female  Female
# 108    Male    Male
# 67     Male    Male
# 133    Male    Male
# 53     Male    Male

# %%
df1 = df.append(df,ignore_index=True)

# %% [raw]
# #Dropping Duplicate Values
#
# df = df.drop_duplicates()

# %%
df1.population[[0,2]]+= 100
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516      300.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Delhi   3.286     1352.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98
# 5        Brazil   Brasilia   8.516      200.40
# 6        Russia     Moscow  17.100      143.50
# 7         India  New Delhi   3.286     1252.00
# 8         China    Beijing   9.597     1357.00
# 9  South Africa   Pretoria   1.221       52.98

# %%
df1.area[0:3] +=2
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia  10.516      300.40
# 1        Russia     Moscow  19.100      143.50
# 2         India  New Delhi   5.286     1352.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98
# 5        Brazil   Brasilia   8.516      200.40
# 6        Russia     Moscow  17.100      143.50
# 7         India  New Delhi   3.286     1252.00
# 8         China    Beijing   9.597     1357.00
# 9  South Africa   Pretoria   1.221       52.98

# %%
df1.drop_duplicates(subset= ['area','population'], keep)
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia  10.516      300.40
# 1        Russia     Moscow  19.100      143.50
# 2         India  New Delhi   5.286     1352.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98
# 5        Brazil   Brasilia   8.516      200.40
# 6        Russia     Moscow  17.100      143.50
# 7         India  New Delhi   3.286     1252.00

# %%
# ?df.drop_duplicates

# %% [raw]
# df.drop_duplicates(subset=None, keep='first', inplace=False)
#
# by default --- remove exact duplicate

# %% [raw]
# Getting unique values of a variable

# %% [raw]
# Joins

# %%
import pandas as pd
left = pd.DataFrame({
         'id':[1,2,3,4,5],
         'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
         'subject_id':['sub1','sub2','sub4','sub6','sub5']})

# %%
right = pd.DataFrame(
         {'id':[1,6,3,4,5],
         'Height': [120,110,115,119,130],
         'subject_id':['sub2','sub4','sub3','sub6','sub5']})

# %%
pd.merge(left,right,on='id', how = 'outer')
# Out:
#      Name  id subject_id_x  Height subject_id_y
# 0    Alex   1         sub1   120.0         sub2
# 1     Amy   2         sub2     NaN          NaN
# 2   Allen   3         sub4   115.0         sub3
# 3   Alice   4         sub6   119.0         sub6
# 4  Ayoung   5         sub5   130.0         sub5
# 5     NaN   6          NaN   110.0         sub4

# %%
pd.merge(left,right,how = 'inner' , on='id')
# Out:
#      Name  id subject_id_x  Height subject_id_y
# 0    Alex   1         sub1     120         sub2
# 1   Allen   3         sub4     115         sub3
# 2   Alice   4         sub6     119         sub6
# 3  Ayoung   5         sub5     130         sub5

# %%
pd.merge(left,right,how = 'left' , on='id')
# Out:
#      Name  id subject_id_x  Height subject_id_y
# 0    Alex   1         sub1   120.0         sub2
# 1     Amy   2         sub2     NaN          NaN
# 2   Allen   3         sub4   115.0         sub3
# 3   Alice   4         sub6   119.0         sub6
# 4  Ayoung   5         sub5   130.0         sub5

# %%
pd.merge(left,right,how = 'right' , on='id', suffixes=('_left','_right'))
# Out:
#      Name  id subject_id_left  Height subject_id_right
# 0    Alex   1            sub1     120             sub2
# 1   Allen   3            sub4     115             sub3
# 2   Alice   4            sub6     119             sub6
# 3  Ayoung   5            sub5     130             sub5
# 4     NaN   6             NaN     110             sub4

# %%
# ?pd.merge

# %%
pd.merge(left,right,how = 'right' , on='id')
emp code
employee code
on
# Out:
#      Name  id subject_id_x  Height subject_id_y
# 0    Alex   1         sub1     120         sub2
# 1   Allen   3         sub4     115         sub3
# 2   Alice   4         sub6     119         sub6
# 3  Ayoung   5         sub5     130         sub5
# 4     NaN   6          NaN     110         sub4

# %%
for lab, row in samp.iterrows():
        print(lab)
        print(row)
# Out:
# 70
# Gender       0
# Race         4
# SEB          1
# School       1
# Prog         1
# Read        57
# Write       52
# Math1       41
# Math2       47
# SST         57
# s_loop    Male
# Sex       Male
# Name: 70, dtype: object
# 171
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         2
# Read        60
# Write       54
# Math1       60
# Math2       55
# SST         66
# s_loop    Male
# Sex       Male
# Name: 171, dtype: object
# 140
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         3
# Read        44
# Write       41
# Math1       40
# Math2       50
# SST         26
# s_loop    Male
# Sex       Male
# Name: 140, dtype: object
# 197
# Gender       0
# Race         4
# SEB          3
# School       2
# Prog         2
# Read        50
# Write       42
# Math1       50
# Math2       36
# SST         61
# s_loop    Male
# Sex       Male
# Name: 197, dtype: object
# 108
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         1
# Read        34
# Write       33
# Math1       41
# Math2       36
# SST         36
# s_loop    Male
# Sex       Male
# Name: 108, dtype: object
# 134
# Gender       0
# Race         4
# SEB          1
# School       1
# Prog         1
# Read        44
# Write       44
# Math1       39
# Math2       34
# SST         46
# s_loop    Male
# Sex       Male
# Name: 134, dtype: object
# 170
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        47
# Write       62
# Math1       61
# Math2       69
# SST         66
# s_loop    Male
# Sex       Male
# Name: 170, dtype: object
# 181
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         2
# Read        50
# Write       46
# Math1       45
# Math2       58
# SST         61
# s_loop    Male
# Sex       Male
# Name: 181, dtype: object
# 9
# Gender       0
# Race         1
# SEB          2
# School       1
# Prog         3
# Read        48
# Write       49
# Math1       52
# Math2       44
# SST         51
# s_loop    Male
# Sex       Male
# Name: 9, dtype: object
# 185
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         2
# Read        63
# Write       57
# Math1       55
# Math2       58
# SST         41
# s_loop    Male
# Sex       Male
# Name: 185, dtype: object
# 22
# Gender       0
# Race         1
# SEB          2
# School       1
# Prog         3
# Read        42
# Write       39
# Math1       39
# Math2       56
# SST         46
# s_loop    Male
# Sex       Male
# Name: 22, dtype: object
# 67
# Gender       0
# Race         4
# SEB          1
# School       1
# Prog         3
# Read        37
# Write       37
# Math1       42
# Math2       33
# SST         32
# s_loop    Male
# Sex       Male
# Name: 67, dtype: object
# 15
# Gender       0
# Race         1
# SEB          3
# School       1
# Prog         3
# Read        39
# Write       39
# Math1       44
# Math2       26
# SST         42
# s_loop    Male
# Sex       Male
# Name: 15, dtype: object
# 132
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         2
# Read        73
# Write       62
# Math1       73
# Math2       69
# SST         66
# s_loop    Male
# Sex       Male
# Name: 132, dtype: object
# 183
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         2
# Read        63
# Write       59
# Math1       49
# Math2       55
# SST         71
# s_loop    Male
# Sex       Male
# Name: 183, dtype: object
# 21
# Gender       0
# Race         1
# SEB          2
# School       1
# Prog         1
# Read        44
# Write       44
# Math1       61
# Math2       50
# SST         46
# s_loop    Male
# Sex       Male
# Name: 21, dtype: object
# 128
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        39
# Write       33
# Math1       38
# Math2       47
# SST         41
# s_loop    Male
# Sex       Male
# Name: 128, dtype: object
# 27
# Gender       0
# Race         2
# SEB          2
# School       1
# Prog         2
# Read        53
# Write       61
# Math1       61
# Math2       57
# SST         56
# s_loop    Male
# Sex       Male
# Name: 27, dtype: object
# 7
# Gender       0
# Race         1
# SEB          2
# School       1
# Prog         2
# Read        57
# Write       54
# Math1       59
# Math2       47
# SST         51
# s_loop    Male
# Sex       Male
# Name: 7, dtype: object
# 189
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         2
# Read        47
# Write       59
# Math1       63
# Math2       53
# SST         46
# s_loop    Male
# Sex       Male
# Name: 189, dtype: object
# 107
# Gender       0
# Race         4
# SEB          1
# School       1
# Prog         3
# Read        47
# Write       39
# Math1       47
# Math2       42
# SST         26
# s_loop    Male
# Sex       Male
# Name: 107, dtype: object
# 81
# Gender       0
# Race         4
# SEB          1
# School       1
# Prog         2
# Read        63
# Write       43
# Math1       59
# Math2       65
# SST         44
# s_loop    Male
# Sex       Male
# Name: 81, dtype: object
# 18
# Gender       0
# Race         1
# SEB          2
# School       1
# Prog         3
# Read        50
# Write       33
# Math1       49
# Math2       44
# SST         36
# s_loop    Male
# Sex       Male
# Name: 18, dtype: object
# 155
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         1
# Read        44
# Write       44
# Math1       46
# Math2       39
# SST         51
# s_loop    Male
# Sex       Male
# Name: 155, dtype: object
# 149
# Gender       0
# Race         4
# SEB          1
# School       1
# Prog         1
# Read        63
# Write       49
# Math1       49
# Math2       66
# SST         46
# s_loop    Male
# Sex       Male
# Name: 149, dtype: object
# 24
# Gender       0
# Race         2
# SEB          2
# School       1
# Prog         2
# Read        52
# Write       62
# Math1       66
# Math2       47
# SST         46
# s_loop    Male
# Sex       Male
# Name: 24, dtype: object
# 94
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        55
# Write       49
# Math1       61
# Math2       61
# SST         56
# s_loop    Male
# Sex       Male
# Name: 94, dtype: object
# 133
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         3
# Read        50
# Write       31
# Math1       40
# Math2       34
# SST         31
# s_loop    Male
# Sex       Male
# Name: 133, dtype: object
# 117
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         3
# Read        34
# Write       49
# Math1       39
# Math2       42
# SST         56
# s_loop    Male
# Sex       Male
# Name: 117, dtype: object
# 102
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        52
# Write       41
# Math1       51
# Math2       53
# SST         56
# s_loop    Male
# Sex       Male
# Name: 102, dtype: object
# 146
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        55
# Write       62
# Math1       64
# Math2       63
# SST         66
# s_loop    Male
# Sex       Male
# Name: 146, dtype: object
# 58
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         3
# Read        55
# Write       41
# Math1       40
# Math2       44
# SST         41
# s_loop    Male
# Sex       Male
# Name: 58, dtype: object
# 3
# Gender       0
# Race         1
# SEB          1
# School       1
# Prog         2
# Read        63
# Write       65
# Math1       48
# Math2       63
# SST         56
# s_loop    Male
# Sex       Male
# Name: 3, dtype: object
# 136
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         2
# Read        65
# Write       59
# Math1       70
# Math2       63
# SST         51
# s_loop    Male
# Sex       Male
# Name: 136, dtype: object
# 174
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         2
# Read        68
# Write       59
# Math1       71
# Math2       66
# SST         56
# s_loop    Male
# Sex       Male
# Name: 174, dtype: object
# 127
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        63
# Write       59
# Math1       57
# Math2       55
# SST         56
# s_loop    Male
# Sex       Male
# Name: 127, dtype: object
# 14
# Gender       0
# Race         1
# SEB          3
# School       1
# Prog         2
# Read        47
# Write       41
# Math1       54
# Math2       42
# SST         56
# s_loop    Male
# Sex       Male
# Name: 14, dtype: object
# 164
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         3
# Read        31
# Write       36
# Math1       46
# Math2       39
# SST         46
# s_loop    Male
# Sex       Male
# Name: 164, dtype: object
# 123
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         1
# Read        68
# Write       59
# Math1       56
# Math2       63
# SST         66
# s_loop    Male
# Sex       Male
# Name: 123, dtype: object
# 159
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        55
# Write       61
# Math1       54
# Math2       49
# SST         61
# s_loop    Male
# Sex       Male
# Name: 159, dtype: object
# 5
# Gender       0
# Race         1
# SEB          1
# School       1
# Prog         2
# Read        47
# Write       40
# Math1       43
# Math2       45
# SST         31
# s_loop    Male
# Sex       Male
# Name: 5, dtype: object
# 56
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         3
# Read        55
# Write       45
# Math1       46
# Math2       58
# SST         51
# s_loop    Male
# Sex       Male
# Name: 56, dtype: object
# 157
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         1
# Read        68
# Write       59
# Math1       58
# Math2       74
# SST         66
# s_loop    Male
# Sex       Male
# Name: 157, dtype: object
# 68
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         2
# Read        73
# Write       67
# Math1       71
# Math2       63
# SST         66
# s_loop    Male
# Sex       Male
# Name: 68, dtype: object
# 165
# Gender       0
# Race         4
# SEB          1
# School       1
# Prog         3
# Read        36
# Write       49
# Math1       54
# Math2       61
# SST         36
# s_loop    Male
# Sex       Male
# Name: 165, dtype: object
# 49
# Gender       0
# Race         3
# SEB          3
# School       1
# Prog         3
# Read        50
# Write       40
# Math1       39
# Math2       49
# SST         47
# s_loop    Male
# Sex       Male
# Name: 49, dtype: object
# 97
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        60
# Write       54
# Math1       58
# Math2       58
# SST         61
# s_loop    Male
# Sex       Male
# Name: 97, dtype: object
# 62
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         1
# Read        65
# Write       65
# Math1       48
# Math2       63
# SST         66
# s_loop    Male
# Sex       Male
# Name: 62, dtype: object
# 167
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         1
# Read        63
# Write       49
# Math1       35
# Math2       66
# SST         41
# s_loop    Male
# Sex       Male
# Name: 167, dtype: object
# 85
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         1
# Read        55
# Write       39
# Math1       57
# Math2       53
# SST         46
# s_loop    Male
# Sex       Male
# Name: 85, dtype: object
# 114
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        68
# Write       65
# Math1       62
# Math2       55
# SST         61
# s_loop    Male
# Sex       Male
# Name: 114, dtype: object
# 195
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         1
# Read        57
# Write       57
# Math1       60
# Math2       58
# SST         56
# s_loop    Male
# Sex       Male
# Name: 195, dtype: object
# 76
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        47
# Write       52
# Math1       51
# Math2       50
# SST         56
# s_loop    Male
# Sex       Male
# Name: 76, dtype: object
# 115
# Gender       0
# Race         4
# SEB          1
# School       1
# Prog         1
# Read        42
# Write       49
# Math1       43
# Math2       50
# SST         56
# s_loop    Male
# Sex       Male
# Name: 115, dtype: object
# 38
# Gender       0
# Race         3
# SEB          1
# School       1
# Prog         2
# Read        45
# Write       57
# Math1       50
# Math2       31
# SST         56
# s_loop    Male
# Sex       Male
# Name: 38, dtype: object
# 104
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        54
# Write       63
# Math1       57
# Math2       55
# SST         46
# s_loop    Male
# Sex       Male
# Name: 104, dtype: object
# 95
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        73
# Write       60
# Math1       71
# Math2       61
# SST         71
# s_loop    Male
# Sex       Male
# Name: 95, dtype: object
# 75
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         3
# Read        60
# Write       46
# Math1       51
# Math2       53
# SST         61
# s_loop    Male
# Sex       Male
# Name: 75, dtype: object
# 48
# Gender       0
# Race         3
# SEB          2
# School       1
# Prog         2
# Read        57
# Write       55
# Math1       52
# Math2       50
# SST         51
# s_loop    Male
# Sex       Male
# Name: 48, dtype: object
# 84
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         1
# Read        63
# Write       57
# Math1       54
# Math2       58
# SST         51
# s_loop    Male
# Sex       Male
# Name: 84, dtype: object
# 11
# Gender       0
# Race         1
# SEB          2
# School       1
# Prog         2
# Read        34
# Write       46
# Math1       45
# Math2       39
# SST         36
# s_loop    Male
# Sex       Male
# Name: 11, dtype: object
# 50
# Gender       0
# Race         3
# SEB          2
# School       1
# Prog         1
# Read        50
# Write       59
# Math1       42
# Math2       53
# SST         61
# s_loop    Male
# Sex       Male
# Name: 50, dtype: object
# 113
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         2
# Read        44
# Write       52
# Math1       51
# Math2       63
# SST         61
# s_loop    Male
# Sex       Male
# Name: 113, dtype: object
# 172
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         2
# Read        47
# Write       52
# Math1       57
# Math2       53
# SST         61
# s_loop    Male
# Sex       Male
# Name: 172, dtype: object
# 141
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         3
# Read        63
# Write       44
# Math1       47
# Math2       53
# SST         56
# s_loop    Male
# Sex       Male
# Name: 141, dtype: object
# 86
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         1
# Read        44
# Write       33
# Math1       54
# Math2       58
# SST         31
# s_loop    Male
# Sex       Male
# Name: 86, dtype: object
# 169
# Gender       0
# Race         4
# SEB          1
# School       1
# Prog         1
# Read        55
# Write       59
# Math1       63
# Math2       69
# SST         46
# s_loop    Male
# Sex       Male
# Name: 169, dtype: object
# 143
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         3
# Read        63
# Write       63
# Math1       75
# Math2       72
# SST         66
# s_loop    Male
# Sex       Male
# Name: 143, dtype: object
# 41
# Gender       0
# Race         3
# SEB          2
# School       1
# Prog         2
# Read        50
# Write       40
# Math1       45
# Math2       55
# SST         56
# s_loop    Male
# Sex       Male
# Name: 41, dtype: object
# 60
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         2
# Read        57
# Write       65
# Math1       51
# Math2       63
# SST         61
# s_loop    Male
# Sex       Male
# Name: 60, dtype: object
# 12
# Gender       0
# Race         1
# SEB          2
# School       1
# Prog         3
# Read        37
# Write       44
# Math1       45
# Math2       39
# SST         46
# s_loop    Male
# Sex       Male
# Name: 12, dtype: object
# 40
# Gender       0
# Race         3
# SEB          1
# School       1
# Prog         1
# Read        42
# Write       41
# Math1       43
# Math2       50
# SST         41
# s_loop    Male
# Sex       Male
# Name: 40, dtype: object
# 20
# Gender       0
# Race         1
# SEB          3
# School       1
# Prog         2
# Read        60
# Write       52
# Math1       57
# Math2       61
# SST         61
# s_loop    Male
# Sex       Male
# Name: 20, dtype: object
# 168
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         2
# Read        52
# Write       54
# Math1       57
# Math2       55
# SST         51
# s_loop    Male
# Sex       Male
# Name: 168, dtype: object
# 177
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         2
# Read        55
# Write       59
# Math1       62
# Math2       58
# SST         51
# s_loop    Male
# Sex       Male
# Name: 177, dtype: object
# 176
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         2
# Read        47
# Write       47
# Math1       41
# Math2       42
# SST         51
# s_loop    Male
# Sex       Male
# Name: 176, dtype: object
# 153
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         3
# Read        39
# Write       31
# Math1       40
# Math2       39
# SST         51
# s_loop    Male
# Sex       Male
# Name: 153, dtype: object
# 16
# Gender       0
# Race         1
# SEB          1
# School       1
# Prog         3
# Read        47
# Write       31
# Math1       44
# Math2       36
# SST         36
# s_loop    Male
# Sex       Male
# Name: 16, dtype: object
# 200
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         2
# Read        68
# Write       54
# Math1       75
# Math2       66
# SST         66
# s_loop    Male
# Sex       Male
# Name: 200, dtype: object
# 144
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         1
# Read        60
# Write       65
# Math1       58
# Math2       61
# SST         66
# s_loop    Male
# Sex       Male
# Name: 144, dtype: object
# 199
# Gender       0
# Race         4
# SEB          3
# School       2
# Prog         2
# Read        52
# Write       59
# Math1       50
# Math2       61
# SST         61
# s_loop    Male
# Sex       Male
# Name: 199, dtype: object
# 80
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        65
# Write       62
# Math1       68
# Math2       66
# SST         66
# s_loop    Male
# Sex       Male
# Name: 80, dtype: object
# 150
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         3
# Read        42
# Write       41
# Math1       57
# Math2       72
# SST         31
# s_loop    Male
# Sex       Male
# Name: 150, dtype: object
# 192
# Gender       0
# Race         4
# SEB          3
# School       2
# Prog         2
# Read        65
# Write       67
# Math1       63
# Math2       66
# SST         71
# s_loop    Male
# Sex       Male
# Name: 192, dtype: object
# 103
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        76
# Write       52
# Math1       64
# Math2       64
# SST         61
# s_loop    Male
# Sex       Male
# Name: 103, dtype: object
# 126
# Gender       0
# Race         4
# SEB          2
# School       1
# Prog         1
# Read        42
# Write       31
# Math1       57
# Math2       47
# SST         51
# s_loop    Male
# Sex       Male
# Name: 126, dtype: object
# 29
# Gender       0
# Race         2
# SEB          1
# School       1
# Prog         1
# Read        52
# Write       44
# Math1       49
# Math2       55
# SST         41
# s_loop    Male
# Sex       Male
# Name: 29, dtype: object
# 196
# Gender       0
# Race         4
# SEB          3
# School       2
# Prog         2
# Read        44
# Write       38
# Math1       49
# Math2       39
# SST         46
# s_loop    Male
# Sex       Male
# Name: 196, dtype: object
# 178
# Gender       0
# Race         4
# SEB          2
# School       2
# Prog         3
# Read        47
# Write       57
# Math1       57
# Math2       58
# SST         46
# s_loop    Male
# Sex       Male
# Name: 178, dtype: object
# 154
# Gender       0
# Race         4
# SEB          3
# School       1
# Prog         2
# Read        65
# Write       65
# Math1       66
# Math2       61
# SST         66
# s_loop    Male
# Sex       Male
# Name: 154, dtype: object
# 53
# Gender       0
# Race         3
# SEB          2
# School       1
# Prog         3
# Read        34
# Write       37
# Math1       46
# Math2       39
# SST         31
# s_loop    Male
# Sex       Male
# Name: 53, dtype: object
# 74
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          57
# Write         50
# Math1         50
# Math2         51
# SST           58
# s_loop    Female
# Sex       Female
# Name: 74, dtype: object
# 198
# Gender         1
# Race           4
# SEB            3
# School         2
# Prog           2
# Read          47
# Write         61
# Math1         51
# Math2         63
# SST           31
# s_loop    Female
# Sex       Female
# Name: 198, dtype: object
# 161
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           2
# Read          57
# Write         62
# Math1         72
# Math2         61
# SST           61
# s_loop    Female
# Sex       Female
# Name: 161, dtype: object
# 112
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          52
# Write         59
# Math1         48
# Math2         55
# SST           61
# s_loop    Female
# Sex       Female
# Name: 112, dtype: object
# 111
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           1
# Read          39
# Write         54
# Math1         39
# Math2         47
# SST           36
# s_loop    Female
# Sex       Female
# Name: 111, dtype: object
# 69
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           3
# Read          44
# Write         44
# Math1         40
# Math2         40
# SST           31
# s_loop    Female
# Sex       Female
# Name: 69, dtype: object
# 156
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          50
# Write         59
# Math1         53
# Math2         61
# SST           61
# s_loop    Female
# Sex       Female
# Name: 156, dtype: object
# 186
# Gender         1
# Race           4
# SEB            2
# School         2
# Prog           2
# Read          57
# Write         62
# Math1         63
# Math2         55
# SST           41
# s_loop    Female
# Sex       Female
# Name: 186, dtype: object
# 147
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           2
# Read          47
# Write         62
# Math1         53
# Math2         53
# SST           61
# s_loop    Female
# Sex       Female
# Name: 147, dtype: object
# 98
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           3
# Read          57
# Write         60
# Math1         51
# Math2         53
# SST           37
# s_loop    Female
# Sex       Female
# Name: 98, dtype: object
# 39
# Gender         1
# Race           3
# SEB            3
# School         1
# Prog           2
# Read          66
# Write         67
# Math1         67
# Math2         61
# SST           66
# s_loop    Female
# Sex       Female
# Name: 39, dtype: object
# 46
# Gender         1
# Race           3
# SEB            1
# School         1
# Prog           2
# Read          45
# Write         55
# Math1         44
# Math2         34
# SST           41
# s_loop    Female
# Sex       Female
# Name: 46, dtype: object
# 148
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          42
# Write         57
# Math1         51
# Math2         47
# SST           61
# s_loop    Female
# Sex       Female
# Name: 148, dtype: object
# 110
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          52
# Write         55
# Math1         50
# Math2         54
# SST           61
# s_loop    Female
# Sex       Female
# Name: 110, dtype: object
# 139
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          68
# Write         59
# Math1         61
# Math2         55
# SST           71
# s_loop    Female
# Sex       Female
# Name: 139, dtype: object
# 71
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           1
# Read          57
# Write         62
# Math1         56
# Math2         58
# SST           66
# s_loop    Female
# Sex       Female
# Name: 71, dtype: object
# 10
# Gender         1
# Race           1
# SEB            2
# School         1
# Prog           1
# Read          47
# Write         54
# Math1         49
# Math2         53
# SST           61
# s_loop    Female
# Sex       Female
# Name: 10, dtype: object
# 138
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          43
# Write         57
# Math1         40
# Math2         50
# SST           51
# s_loop    Female
# Sex       Female
# Name: 138, dtype: object
# 96
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          65
# Write         54
# Math1         61
# Math2         58
# SST           56
# s_loop    Female
# Sex       Female
# Name: 96, dtype: object
# 43
# Gender         1
# Race           3
# SEB            1
# School         1
# Prog           2
# Read          47
# Write         37
# Math1         43
# Math2         42
# SST           46
# s_loop    Female
# Sex       Female
# Name: 43, dtype: object
# 6
# Gender         1
# Race           1
# SEB            1
# School         1
# Prog           2
# Read          47
# Write         41
# Math1         46
# Math2         40
# SST           41
# s_loop    Female
# Sex       Female
# Name: 6, dtype: object
# 119
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           1
# Read          42
# Write         57
# Math1         45
# Math2         50
# SST           43
# s_loop    Female
# Sex       Female
# Name: 119, dtype: object
# 182
# Gender         1
# Race           4
# SEB            2
# School         2
# Prog           2
# Read          44
# Write         52
# Math1         43
# Math2         44
# SST           51
# s_loop    Female
# Sex       Female
# Name: 182, dtype: object
# 109
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           1
# Read          42
# Write         39
# Math1         42
# Math2         42
# SST           41
# s_loop    Female
# Sex       Female
# Name: 109, dtype: object
# 13
# Gender         1
# Race           1
# SEB            2
# School         1
# Prog           3
# Read          47
# Write         46
# Math1         39
# Math2         47
# SST           61
# s_loop    Female
# Sex       Female
# Name: 13, dtype: object
# 30
# Gender         1
# Race           2
# SEB            3
# School         1
# Prog           2
# Read          41
# Write         59
# Math1         42
# Math2         34
# SST           51
# s_loop    Female
# Sex       Female
# Name: 30, dtype: object
# 26
# Gender         1
# Race           2
# SEB            3
# School         1
# Prog           2
# Read          60
# Write         59
# Math1         62
# Math2         61
# SST           51
# s_loop    Female
# Sex       Female
# Name: 26, dtype: object
# 83
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          50
# Write         62
# Math1         41
# Math2         55
# SST           31
# s_loop    Female
# Sex       Female
# Name: 83, dtype: object
# 187
# Gender         1
# Race           4
# SEB            2
# School         2
# Prog           1
# Read          57
# Write         41
# Math1         57
# Math2         55
# SST           52
# s_loop    Female
# Sex       Female
# Name: 187, dtype: object
# 145
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          42
# Write         46
# Math1         38
# Math2         36
# SST           46
# s_loop    Female
# Sex       Female
# Name: 145, dtype: object
# 31
# Gender         1
# Race           2
# SEB            2
# School         2
# Prog           1
# Read          55
# Write         59
# Math1         52
# Math2         42
# SST           56
# s_loop    Female
# Sex       Female
# Name: 31, dtype: object
# 179
# Gender         1
# Race           4
# SEB            2
# School         2
# Prog           2
# Read          47
# Write         65
# Math1         60
# Math2         50
# SST           56
# s_loop    Female
# Sex       Female
# Name: 179, dtype: object
# 184
# Gender         1
# Race           4
# SEB            2
# School         2
# Prog           3
# Read          50
# Write         52
# Math1         53
# Math2         55
# SST           56
# s_loop    Female
# Sex       Female
# Name: 184, dtype: object
# 175
# Gender         1
# Race           4
# SEB            3
# School         2
# Prog           1
# Read          36
# Write         57
# Math1         42
# Math2         50
# SST           41
# s_loop    Female
# Sex       Female
# Name: 175, dtype: object
# 124
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           3
# Read          42
# Write         54
# Math1         41
# Math2         42
# SST           41
# s_loop    Female
# Sex       Female
# Name: 124, dtype: object
# 52
# Gender         1
# Race           3
# SEB            1
# School         1
# Prog           2
# Read          50
# Write         46
# Math1         53
# Math2         53
# SST           66
# s_loop    Female
# Sex       Female
# Name: 52, dtype: object
# 188
# Gender         1
# Race           4
# SEB            3
# School         2
# Prog           2
# Read          63
# Write         62
# Math1         56
# Math2         55
# SST           61
# s_loop    Female
# Sex       Female
# Name: 188, dtype: object
# 25
# Gender         1
# Race           2
# SEB            2
# School         1
# Prog           1
# Read          47
# Write         44
# Math1         42
# Math2         42
# SST           36
# s_loop    Female
# Sex       Female
# Name: 25, dtype: object
# 51
# Gender         1
# Race           3
# SEB            3
# School         1
# Prog           1
# Read          42
# Write         36
# Math1         42
# Math2         31
# SST           39
# s_loop    Female
# Sex       Female
# Name: 51, dtype: object
# 158
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           1
# Read          52
# Write         54
# Math1         55
# Math2         53
# SST           51
# s_loop    Female
# Sex       Female
# Name: 158, dtype: object
# 32
# Gender         1
# Race           2
# SEB            3
# School         1
# Prog           3
# Read          50
# Write         67
# Math1         66
# Math2         66
# SST           56
# s_loop    Female
# Sex       Female
# Name: 32, dtype: object
# 160
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          55
# Write         65
# Math1         55
# Math2         50
# SST           61
# s_loop    Female
# Sex       Female
# Name: 160, dtype: object
# 92
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           1
# Read          52
# Write         67
# Math1         57
# Math2         63
# SST           61
# s_loop    Female
# Sex       Female
# Name: 92, dtype: object
# 193
# Gender         1
# Race           4
# SEB            2
# School         2
# Prog           2
# Read          44
# Write         49
# Math1         48
# Math2         39
# SST           51
# s_loop    Female
# Sex       Female
# Name: 193, dtype: object
# 79
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          60
# Write         62
# Math1         49
# Math2         50
# SST           51
# s_loop    Female
# Sex       Female
# Name: 79, dtype: object
# 63
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           1
# Read          52
# Write         65
# Math1         60
# Math2         56
# SST           51
# s_loop    Female
# Sex       Female
# Name: 63, dtype: object
# 64
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           3
# Read          50
# Write         52
# Math1         45
# Math2         58
# SST           36
# s_loop    Female
# Sex       Female
# Name: 64, dtype: object
# 78
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          39
# Write         54
# Math1         54
# Math2         53
# SST           41
# s_loop    Female
# Sex       Female
# Name: 78, dtype: object
# 59
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          65
# Write         67
# Math1         63
# Math2         55
# SST           71
# s_loop    Female
# Sex       Female
# Name: 59, dtype: object
# 135
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           2
# Read          63
# Write         60
# Math1         65
# Math2         54
# SST           66
# s_loop    Female
# Sex       Female
# Name: 135, dtype: object
# 36
# Gender         1
# Race           3
# SEB            1
# School         1
# Prog           1
# Read          44
# Write         49
# Math1         44
# Math2         35
# SST           51
# s_loop    Female
# Sex       Female
# Name: 36, dtype: object
# 23
# Gender         1
# Race           2
# SEB            1
# School         1
# Prog           2
# Read          65
# Write         65
# Math1         64
# Math2         58
# SST           71
# s_loop    Female
# Sex       Female
# Name: 23, dtype: object
# 191
# Gender         1
# Race           4
# SEB            3
# School         2
# Prog           2
# Read          47
# Write         52
# Math1         43
# Math2         48
# SST           61
# s_loop    Female
# Sex       Female
# Name: 191, dtype: object
# 194
# Gender         1
# Race           4
# SEB            3
# School         2
# Prog           2
# Read          63
# Write         63
# Math1         69
# Math2         61
# SST           61
# s_loop    Female
# Sex       Female
# Name: 194, dtype: object
# 17
# Gender         1
# Race           1
# SEB            2
# School         1
# Prog           2
# Read          47
# Write         57
# Math1         48
# Math2         44
# SST           41
# s_loop    Female
# Sex       Female
# Name: 17, dtype: object
# 34
# Gender         1
# Race           1
# SEB            3
# School         2
# Prog           2
# Read          73
# Write         61
# Math1         57
# Math2         55
# SST           66
# s_loop    Female
# Sex       Female
# Name: 34, dtype: object
# 125
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           2
# Read          68
# Write         65
# Math1         58
# Math2         59
# SST           56
# s_loop    Female
# Sex       Female
# Name: 125, dtype: object
# 131
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          65
# Write         59
# Math1         57
# Math2         46
# SST           66
# s_loop    Female
# Sex       Female
# Name: 131, dtype: object
# 4
# Gender         1
# Race           1
# SEB            1
# School         1
# Prog           2
# Read          44
# Write         50
# Math1         41
# Math2         39
# SST           51
# s_loop    Female
# Sex       Female
# Name: 4, dtype: object
# 162
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          57
# Write         52
# Math1         40
# Math2         61
# SST           56
# s_loop    Female
# Sex       Female
# Name: 162, dtype: object
# 180
# Gender         1
# Race           4
# SEB            3
# School         2
# Prog           2
# Read          71
# Write         65
# Math1         69
# Math2         58
# SST           71
# s_loop    Female
# Sex       Female
# Name: 180, dtype: object
# 54
# Gender         1
# Race           3
# SEB            1
# School         2
# Prog           1
# Read          47
# Write         54
# Math1         46
# Math2         50
# SST           56
# s_loop    Female
# Sex       Female
# Name: 54, dtype: object
# 89
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           3
# Read          35
# Write         35
# Math1         40
# Math2         51
# SST           33
# s_loop    Female
# Sex       Female
# Name: 89, dtype: object
# 101
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          60
# Write         62
# Math1         67
# Math2         50
# SST           56
# s_loop    Female
# Sex       Female
# Name: 101, dtype: object
# 65
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          55
# Write         54
# Math1         66
# Math2         42
# SST           56
# s_loop    Female
# Sex       Female
# Name: 65, dtype: object
# 166
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          52
# Write         59
# Math1         53
# Math2         61
# SST           51
# s_loop    Female
# Sex       Female
# Name: 166, dtype: object
# 106
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          36
# Write         44
# Math1         37
# Math2         42
# SST           41
# s_loop    Female
# Sex       Female
# Name: 106, dtype: object
# 120
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          63
# Write         52
# Math1         54
# Math2         50
# SST           51
# s_loop    Female
# Sex       Female
# Name: 120, dtype: object
# 99
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           1
# Read          47
# Write         59
# Math1         56
# Math2         66
# SST           61
# s_loop    Female
# Sex       Female
# Name: 99, dtype: object
# 88
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          68
# Write         60
# Math1         64
# Math2         69
# SST           66
# s_loop    Female
# Sex       Female
# Name: 88, dtype: object
# 118
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           1
# Read          55
# Write         62
# Math1         58
# Math2         58
# SST           61
# s_loop    Female
# Sex       Female
# Name: 118, dtype: object
# 1
# Gender         1
# Race           1
# SEB            1
# School         1
# Prog           3
# Read          34
# Write         44
# Math1         40
# Math2         39
# SST           41
# s_loop    Female
# Sex       Female
# Name: 1, dtype: object
# 100
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          63
# Write         65
# Math1         71
# Math2         69
# SST           71
# s_loop    Female
# Sex       Female
# Name: 100, dtype: object
# 57
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          71
# Write         65
# Math1         72
# Math2         66
# SST           56
# s_loop    Female
# Sex       Female
# Name: 57, dtype: object
# 173
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           1
# Read          50
# Write         62
# Math1         61
# Math2         63
# SST           51
# s_loop    Female
# Sex       Female
# Name: 173, dtype: object
# 129
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           1
# Read          44
# Write         44
# Math1         46
# Math2         47
# SST           51
# s_loop    Female
# Sex       Female
# Name: 129, dtype: object
# 8
# Gender         1
# Race           1
# SEB            1
# School         1
# Prog           2
# Read          39
# Write         44
# Math1         52
# Math2         44
# SST           48
# s_loop    Female
# Sex       Female
# Name: 8, dtype: object
# 82
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          68
# Write         62
# Math1         65
# Math2         69
# SST           61
# s_loop    Female
# Sex       Female
# Name: 82, dtype: object
# 121
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          68
# Write         59
# Math1         53
# Math2         63
# SST           61
# s_loop    Female
# Sex       Female
# Name: 121, dtype: object
# 47
# Gender         1
# Race           3
# SEB            1
# School         1
# Prog           2
# Read          47
# Write         46
# Math1         49
# Math2         33
# SST           41
# s_loop    Female
# Sex       Female
# Name: 47, dtype: object
# 122
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          52
# Write         59
# Math1         58
# Math2         53
# SST           66
# s_loop    Female
# Sex       Female
# Name: 122, dtype: object
# 130
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           1
# Read          43
# Write         54
# Math1         55
# Math2         55
# SST           46
# s_loop    Female
# Sex       Female
# Name: 130, dtype: object
# 163
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           2
# Read          52
# Write         57
# Math1         64
# Math2         58
# SST           56
# s_loop    Female
# Sex       Female
# Name: 163, dtype: object
# 142
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          47
# Write         42
# Math1         52
# Math2         39
# SST           51
# s_loop    Female
# Sex       Female
# Name: 142, dtype: object
# 90
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          42
# Write         54
# Math1         50
# Math2         50
# SST           52
# s_loop    Female
# Sex       Female
# Name: 90, dtype: object
# 19
# Gender         1
# Race           1
# SEB            1
# School         1
# Prog           1
# Read          28
# Write         46
# Math1         43
# Math2         44
# SST           51
# s_loop    Female
# Sex       Female
# Name: 19, dtype: object
# 55
# Gender         1
# Race           3
# SEB            2
# School         2
# Prog           2
# Read          52
# Write         49
# Math1         49
# Math2         44
# SST           61
# s_loop    Female
# Sex       Female
# Name: 55, dtype: object
# 2
# Gender         1
# Race           1
# SEB            2
# School         1
# Prog           3
# Read          39
# Write         41
# Math1         33
# Math2         42
# SST           41
# s_loop    Female
# Sex       Female
# Name: 2, dtype: object
# 42
# Gender         1
# Race           3
# SEB            2
# School         1
# Prog           3
# Read          46
# Write         52
# Math1         55
# Math2         44
# SST           56
# s_loop    Female
# Sex       Female
# Name: 42, dtype: object
# 190
# Gender         1
# Race           4
# SEB            2
# School         2
# Prog           2
# Read          47
# Write         59
# Math1         54
# Math2         58
# SST           46
# s_loop    Female
# Sex       Female
# Name: 190, dtype: object
# 61
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          76
# Write         63
# Math1         60
# Math2         67
# SST           66
# s_loop    Female
# Sex       Female
# Name: 61, dtype: object
# 77
# Gender         1
# Race           4
# SEB            1
# School         1
# Prog           2
# Read          61
# Write         59
# Math1         49
# Math2         44
# SST           66
# s_loop    Female
# Sex       Female
# Name: 77, dtype: object
# 72
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          42
# Write         54
# Math1         47
# Math2         47
# SST           46
# s_loop    Female
# Sex       Female
# Name: 72, dtype: object
# 66
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          68
# Write         62
# Math1         56
# Math2         50
# SST           51
# s_loop    Female
# Sex       Female
# Name: 66, dtype: object
# 93
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          73
# Write         67
# Math1         62
# Math2         58
# SST           66
# s_loop    Female
# Sex       Female
# Name: 93, dtype: object
# 33
# Gender         1
# Race           2
# SEB            1
# School         1
# Prog           2
# Read          57
# Write         65
# Math1         72
# Math2         54
# SST           56
# s_loop    Female
# Sex       Female
# Name: 33, dtype: object
# 45
# Gender         1
# Race           3
# SEB            1
# School         1
# Prog           3
# Read          34
# Write         35
# Math1         41
# Math2         29
# SST           26
# s_loop    Female
# Sex       Female
# Name: 45, dtype: object
# 91
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           3
# Read          50
# Write         49
# Math1         56
# Math2         47
# SST           46
# s_loop    Female
# Sex       Female
# Name: 91, dtype: object
# 28
# Gender         1
# Race           2
# SEB            2
# School         1
# Prog           1
# Read          39
# Write         53
# Math1         54
# Math2         50
# SST           41
# s_loop    Female
# Sex       Female
# Name: 28, dtype: object
# 105
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          50
# Write         41
# Math1         45
# Math2         44
# SST           56
# s_loop    Female
# Sex       Female
# Name: 105, dtype: object
# 152
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          55
# Write         57
# Math1         56
# Math2         58
# SST           61
# s_loop    Female
# Sex       Female
# Name: 152, dtype: object
# 44
# Gender         1
# Race           3
# SEB            1
# School         1
# Prog           3
# Read          47
# Write         62
# Math1         45
# Math2         34
# SST           46
# s_loop    Female
# Sex       Female
# Name: 44, dtype: object
# 151
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           3
# Read          47
# Write         46
# Math1         52
# Math2         48
# SST           46
# s_loop    Female
# Sex       Female
# Name: 151, dtype: object
# 73
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          50
# Write         52
# Math1         53
# Math2         39
# SST           56
# s_loop    Female
# Sex       Female
# Name: 73, dtype: object
# 87
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           1
# Read          50
# Write         52
# Math1         46
# Math2         50
# SST           56
# s_loop    Female
# Sex       Female
# Name: 87, dtype: object
# 35
# Gender         1
# Race           1
# SEB            1
# School         2
# Prog           1
# Read          60
# Write         54
# Math1         50
# Math2         50
# SST           51
# s_loop    Female
# Sex       Female
# Name: 35, dtype: object
# 37
# Gender         1
# Race           3
# SEB            1
# School         1
# Prog           3
# Read          41
# Write         47
# Math1         40
# Math2         39
# SST           51
# s_loop    Female
# Sex       Female
# Name: 37, dtype: object
# 116
# Gender         1
# Race           4
# SEB            2
# School         1
# Prog           2
# Read          57
# Write         59
# Math1         54
# Math2         50
# SST           56
# s_loop    Female
# Sex       Female
# Name: 116, dtype: object
# 137
# Gender         1
# Race           4
# SEB            3
# School         1
# Prog           2
# Read          63
# Write         65
# Math1         65
# Math2         53
# SST           61
# s_loop    Female
# Sex       Female
# Name: 137, dtype: object

# %%
for lab, row in samp.iterrows():
    print(lab,": ",row["Gender"])
# Out:
# 70 :  0
# 171 :  0
# 140 :  0
# 197 :  0
# 108 :  0
# 134 :  0
# 170 :  0
# 181 :  0
# 9 :  0
# 185 :  0
# 22 :  0
# 67 :  0
# 15 :  0
# 132 :  0
# 183 :  0
# 21 :  0
# 128 :  0
# 27 :  0
# 7 :  0
# 189 :  0
# 107 :  0
# 81 :  0
# 18 :  0
# 155 :  0
# 149 :  0
# 24 :  0
# 94 :  0
# 133 :  0
# 117 :  0
# 102 :  0
# 146 :  0
# 58 :  0
# 3 :  0
# 136 :  0
# 174 :  0
# 127 :  0
# 14 :  0
# 164 :  0
# 123 :  0
# 159 :  0
# 5 :  0
# 56 :  0
# 157 :  0
# 68 :  0
# 165 :  0
# 49 :  0
# 97 :  0
# 62 :  0
# 167 :  0
# 85 :  0
# 114 :  0
# 195 :  0
# 76 :  0
# 115 :  0
# 38 :  0
# 104 :  0
# 95 :  0
# 75 :  0
# 48 :  0
# 84 :  0
# 11 :  0
# 50 :  0
# 113 :  0
# 172 :  0
# 141 :  0
# 86 :  0
# 169 :  0
# 143 :  0
# 41 :  0
# 60 :  0
# 12 :  0
# 40 :  0
# 20 :  0
# 168 :  0
# 177 :  0
# 176 :  0
# 153 :  0
# 16 :  0
# 200 :  0
# 144 :  0
# 199 :  0
# 80 :  0
# 150 :  0
# 192 :  0
# 103 :  0
# 126 :  0
# 29 :  0
# 196 :  0
# 178 :  0
# 154 :  0
# 53 :  0
# 74 :  1
# 198 :  1
# 161 :  1
# 112 :  1
# 111 :  1
# 69 :  1
# 156 :  1
# 186 :  1
# 147 :  1
# 98 :  1
# 39 :  1
# 46 :  1
# 148 :  1
# 110 :  1
# 139 :  1
# 71 :  1
# 10 :  1
# 138 :  1
# 96 :  1
# 43 :  1
# 6 :  1
# 119 :  1
# 182 :  1
# 109 :  1
# 13 :  1
# 30 :  1
# 26 :  1
# 83 :  1
# 187 :  1
# 145 :  1
# 31 :  1
# 179 :  1
# 184 :  1
# 175 :  1
# 124 :  1
# 52 :  1
# 188 :  1
# 25 :  1
# 51 :  1
# 158 :  1
# 32 :  1
# 160 :  1
# 92 :  1
# 193 :  1
# 79 :  1
# 63 :  1
# 64 :  1
# 78 :  1
# 59 :  1
# 135 :  1
# 36 :  1
# 23 :  1
# 191 :  1
# 194 :  1
# 17 :  1
# 34 :  1
# 125 :  1
# 131 :  1
# 4 :  1
# 162 :  1
# 180 :  1
# 54 :  1
# 89 :  1
# 101 :  1
# 65 :  1
# 166 :  1
# 106 :  1
# 120 :  1
# 99 :  1
# 88 :  1
# 118 :  1
# 1 :  1
# 100 :  1
# 57 :  1
# 173 :  1
# 129 :  1
# 8 :  1
# 82 :  1
# 121 :  1
# 47 :  1
# 122 :  1
# 130 :  1
# 163 :  1
# 142 :  1
# 90 :  1
# 19 :  1
# 55 :  1
# 2 :  1
# 42 :  1
# 190 :  1
# 61 :  1
# 77 :  1
# 72 :  1
# 66 :  1
# 93 :  1
# 33 :  1
# 45 :  1
# 91 :  1
# 28 :  1
# 105 :  1
# 152 :  1
# 44 :  1
# 151 :  1
# 73 :  1
# 87 :  1
# 35 :  1
# 37 :  1
# 116 :  1
# 137 :  1

# %%
for lab,row in brics.iterrows():
    brics.loc[lab,"length_country"] = len(row["country"])
brics
# Out:
#         country    capital    area  population  pop_int pop_str  pop_float  \
# A        Brazil   Brasilia   8.516      200.40      200   200.4     200.40
# B        Russia     Moscow  17.100      143.50      143   143.5     143.50
# C         India  New Delhi   3.286     1252.00     1252  1252.0    1252.00
# D         China    Beijing   9.597     1357.00     1357  1357.0    1357.00
# E  South Africa   Pretoria   1.221       52.98       52   52.98      52.98
#
#    length_country
# A             6.0
# B             6.0
# C             5.0
# D             5.0
# E            12.0

# %%
brics["name_length"] = brics["country"].apply(len)

# %%
brics
# Out:
#         country    capital    area  population  pop_int pop_str  pop_float  \
# A        Brazil   Brasilia   8.516      200.40      200   200.4     200.40
# B        Russia     Moscow  17.100      143.50      143   143.5     143.50
# C         India  New Delhi   3.286     1252.00     1252  1252.0    1252.00
# D         China    Beijing   9.597     1357.00     1357  1357.0    1357.00
# E  South Africa   Pretoria   1.221       52.98       52   52.98      52.98
#
#    length_country  name_length
# A             6.0            6
# B             6.0            6
# C             5.0            5
# D             5.0            5
# E            12.0           12

# %% [raw]
# exporting to csv and excel

# %%
brics.to_excel('m1.xlsx')

# %%
brics.to_csv('m2.csv')

# %%
brics.to_excel('m.xlsx',index=False)

# %%
import numpy as np

# %%
#Reading dat files

df = pd.read_table("movies.dat",sep='::',header=None, names = ["MovieID","Title", "genre"])
