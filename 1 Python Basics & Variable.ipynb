# %% [markdown]
# # Python basics

# %% [markdown]
# ### Datatypes

# %%
a=5+5

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b=5.2+2.4

# %%
b
# Out:
# 7.6

# %%
type(b)
# Out:
# float

# %%
c='i am learning python'

# %%
c
# Out:
# 'i am learning python'

# %%
type(c)
# Out:
# str

# %%
# we cannot use i as complex number in python. we use j

# %%
d=2j

# %%
d
# Out:
# 2j

# %%
type(d)
# Out:
# complex

# %% [markdown]
# ### Varibales

# %% [markdown]
# A Programmer should always choose a meaningful name for their variable.

# %%
# To create a variable in Python we use the assignment statement 
# variable name can be a-z , A-Z , 0-9 , _
# First we cannot have numbers

# %% [markdown]
# Variable name  assignment operator( = )   value

# %%
data1= 55/11

# %%
data1
# Out:
# 5.0

# %% [markdown]
# Variable name cannot start with number

# %%
1data=22*2
# Out:
#   File "<ipython-input-18-ab0c4ce62ce5>", line 1
#     1data=22*2
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Variable name cannot start with special character except underscore

# %%
$data1=33-2
# Out:
#   File "<ipython-input-21-4ea404aecab4>", line 1
#     $data1=33-2
#     ^
# SyntaxError: invalid syntax

# %%
data$1=4*3
# Out:
#   File "<ipython-input-27-baf160a8fa11>", line 1
#     data$1=4*3
#         ^
# SyntaxError: invalid syntax

# %%
_data1=33-2

# %%
_data1
# Out:
# 31

# %% [markdown]
# #### Error debugging---NameError

# %%
data2='i live in mumbai'

# %%
data2
# Out:
# 'i live in mumbai'

# %%
# Python Keywords cannot be used as vaiable name

# %%
break='today its not raining'
# Out:
#   File "<ipython-input-28-95afd0acf1d0>", line 1
#     break='today its not raining'
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
#   ![image.png](attachment:image.png)

# %% [markdown]
# #### Rules for Variable Names:`

# %% [markdown]
# * A variable can contain both letters and numbers, but they cannot start with a number.
#
#    #So, variable1 is valid while 1variable is a invalid name.
#
# * You may use uppercase letters for variable names but it is always perfectly fine to begin variable names with a lowercase letter.
#
#   *If your Variable name is long, then you can use underscore character (_) in the name.
#
#    #For example, top_five_members, var_1 etc. all are valid example.
#
#
# * You can’t use special characters like !, @, #, $, % etc. in variable name.
#
#
# * Python keywords cannot be used as variable name.

# %% [markdown]
# http://makemeanalyst.com/python-programming/variable-names-and-keywords/

# %%
a=5+0.0000000000000000000000000000034

# %%
a
# Out:
# 5.0

# %%
10/2
# Out:
# 5.0

# %%
10//2
# Out:
# 5

# %% [markdown]
# ### Escape Sequence

# %%
text1='"i live in mumbai\n"" its capital of maharashtra"'

# %%
text1
# Out:
# '"i live in mumbai\n"" its capital of maharashtra"'

# %%
""" this is my notebook





      """
# Out:
# ' this is my notebook\n\n\n\n\n\n      '

# %%
2+data2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-f88001362e17> in <module>
# ----> 1 2+data2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Strings literals in python are surrounded by either single quotation marks, or double quotation marks.

# %%
a='it rain's today'
# Out:
#   File "<ipython-input-66-e1564a92727c>", line 1
#     a='it rain's today'
#                ^
# SyntaxError: invalid syntax

# %%
b="it  rain's today"

# %%
c='"it will rain today"'

# %%
a
# Out:
# 'it will rain today'

# %%
b
# Out:
# 'it will rain today'

# %%
c
# Out:
# '"it will rain today"'

# %% [markdown]
# acessing elements in python

# %%
c='i am learning python'

# %%
c[0]
# Out:
# 'i'

# %%
c[1]
# Out:
# ' '

# %%
c[2:6]
# Out:
# 'am l'

# %%
c[14:]
# Out:
# 'python'

# %%
c[-1:]
# Out:
# 'n'

# %%
c[-7:]
# Out:
# ' python'

# %%
-7-6-5-4-3-2-1

# %%
len(c)
# Out:
# 20

# %%
c.upper()
# Out:
# 'I AM LEARNING PYTHON'

# %%
c.lower()
# Out:
# 'i am learning python'

# %% [markdown]
# ### Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Comparison Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=5
y=2

# %%
x==y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
x>y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
x>=y
# Out:
# True

# %% [markdown]
# ### Logical Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a,b,c=10,20,30

# %% [markdown]
# #### OR

# %%
# OR - both condition true

# %%
(a<b) or (b<c)
# Out:
# True

# %%
# OR - One condtion true other condition false

# %%
(a>b) or (b<c)
# Out:
# True

# %%
# OR Both condition false

# %%
(a>b) or (b>c)
# Out:
# False

# %% [markdown]
# #### AND

# %%
# And - both condition true

# %%
(a<b) and (b<c)
# Out:
# True

# %%
# And - One condtion true other condition false

# %%
(a>b) and (b<c)
# Out:
# False

# %%
# Both condition false

# %%
(a>b) and (b>c)
# Out:
# False

# %%
a
# Out:
# 10

# %%
not a==b
# Out:
# True

# %% [markdown]
# #### Membership Operators

# %% [markdown]
# * These operators test for membership in a sequence such as lists, strings or tuples.
#
# * There are two membership operators that are used in Python. (in, not in).

# %% [markdown]
# Example: For example here we check whether the value of x=4 and value of y=8 is available in list or not, by using in and not in operators.

# %%
x,y=4,8

# %%
list = [1, 2, 3, 4, 5 ]

# %%
if ( x in list ):
   print("Line 1 - x is available in the given list")
else:
   print("Line 1 - x is not available in the given list")
if ( y not in list ):
   print("Line 2 - y is not available in the given list")
else:
   print("Line 2 - y is available in the given list")
# Out:
# Line 1 - x is available in the given list
# Line 2 - y is not available in the given list
